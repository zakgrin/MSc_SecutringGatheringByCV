# %% [markdown]
# # One Shot Learning for Computing Face Similarities using Siamese Network

# %%
import os
import re
import pickle
import time
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import face_recognition
#import dlib
from utilities import face_detect, face_draw

from sklearn.utils import shuffle
from sklearn.preprocessing import Normalizer
from sklearn.metrics import accuracy_score, confusion_matrix, recall_score, precision_score

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K

import tensorflow as tf
from utilities.pca_plotter import PCAPlotter

# %% [markdown]
# ## Create Datasets

# %%
create = False

# %%
def load_images(images_folder, n_persons, n_samples, face_size=(100,100),
                search_limit=10, train_persons_list=[], diagnose=False):
    '''
    images_folder: images folder to load images
    '''
    # init info holders
    X_images = []
    X_embeds = []
    y = []
    videos_dict = dict()
    persons_dict = dict()
    failed_persons = []
    # init counters
    label = 0
    count = 0
    trial = 0
    
    # get names of all available persons
    persons = [folder for folder in os.listdir(images_folder) \
               if os.path.isdir(os.path.join(images_folder,folder))]
    # load a random person's data
    while len([*persons_dict]) < n_persons:
        person = np.random.choice(persons, 1)[0]
        if person in [*persons_dict] or person in train_persons_list or person in failed_persons:
            print(person,'was checked before!')
            continue
        print('- loading data for: ' + person)
        videos_path = os.path.join(images_folder, person)
        videos = os.listdir(videos_path)
        person_images = []
        person_embeds = []
        frame_sample_list = []
        while len(person_images) < n_samples and trial < search_limit:
            trial+=1
            video_sample = np.random.choice(videos, 1)[0]
            frames_path = os.path.join(videos_path, video_sample)
            frames = os.listdir(frames_path)
            frame_sample = np.random.choice(frames, 1)[0]
            if frame_sample in frame_sample_list:
                print('     (',frame_sample,'frame was used before!)')
                continue
            #person_dict[count] = (person, video)
            frame_path = os.path.join(frames_path, frame_sample)
            frame_image = cv2.cvtColor(cv2.imread(frame_path), cv2.COLOR_BGR2RGB)
            face_output = face_detect.detect_faces_in_images(frame_path,
                                                             detector='onnx',
                                                             recognizer='facenet',
                                                             lib='pil',
                                                             report=False,
                                                             show_images=diagnose,
                                                             save_images=False,
                                                             label_faces=True,
                                                             show_landmarks=False,
                                                             show_axes=False,
                                                             return_option='dict')

            face_locations = face_output['location']
            face_embeddings = face_output['embedding']
            
            #face_locations_r = read_face_locations(frame_path)
            #report_dict = {'process_time':0,'labels_probs':0, 'channels':'rgb'}
            #labeled_image = face_draw.face_locations(frame_image,report_dict,face_locations, None, show_points=True)
            #cv2.imshow('output',labeled_image)
            #cv2.waitKey(0)            
            #print(face_locations, face_locations_r)
            print('   - frame file: {0} - (number of faces: {1})'.format(frame_sample,len(face_locations)))
            if len(face_locations) == 1:
                # face image
                top,right,bottom,left = face_locations[0]
                face_image = frame_image[top:bottom,left:right]
                if diagnose:
                    cv2.imshow('output',cv2.cvtColor(face_image, cv2.COLOR_RGB2BGR))
                    cv2.waitKey(0)
                # try to crop resize the image
                try:
                    face_image = cv2.resize(face_image, face_size)
                # if error, then take another trial
                except:
                    continue
                if diagnose:
                    cv2.imshow('output',cv2.cvtColor(face_image, cv2.COLOR_RGB2BGR))
                    cv2.waitKey(0)
                person_images.append(face_image)
                # face embed
                face_embed = np.expand_dims(face_embeddings[0], axis=1)
                person_embeds.append(face_embed)
                # add data
                frame_sample_list.append(frame_sample)
                y.append(label)

        print('     (number of trials: {0} - number of samples: {1})'.format(trial, len(person_images)))
        if trial == search_limit and len(person_images) != n_samples:
            print("    ", person, "search limit was reached!. Look for another person's data")
            failed_persons.append(person)
        else:
            try:
                X_images.append(np.stack(person_images))
                X_embeds.append(np.stack(person_embeds))
            except ValueError as e:
                print('Error: ', e)
                #print("error - person_images: ", person_images)
            persons_dict[person] = [count, count+n_samples-1]
            count+=n_samples
            label+=1
        trial=0
    if diagnose: cv2.destroyAllWindows()
    X_images = np.stack(X_images)
    X_embeds = np.stack(X_embeds)
    y = np.vstack(y)
    print('selected persons:', [*persons_dict])
    return X_images, X_embeds, y, persons_dict

# %%
images_path = 'input/frame_images_DB'
n_persons = 100
n_samples = 20
trials = 100
face_size = (100,100)

if create:    
    X_images_train, X_embeds_train, y_train, persons_dict_train = load_images(images_path, n_persons, n_samples, 
                                                                          face_size, trials, diagnose=False)

# %%
if create:
    file_name = "train_npersons_{}_nsamples_{}.pickle".format(n_persons, n_samples)

    with open("output/train_test_data/"+file_name, "wb") as f:
        pickle.dump((X_images_train, X_embeds_train, y_train, persons_dict_train),f)

# %%
if create:
    n_persons = 20
    X_images_test, X_embeds_test, y_test, persons_dict_test = load_images(images_path, n_persons, n_samples, 
                                                                      face_size, trials, diagnose=False,
                                                                      train_persons_list=[*persons_dict_train])

# %%
if create:
    file_name = "test_npersons_{}_nsamples_{}.pickle".format(n_persons, n_samples)

    with open("output/train_test_data/"+file_name, "wb") as f:
        pickle.dump((X_images_test, X_embeds_test, y_test, persons_dict_test),f)

# %% [markdown]
# - Note: Youtube Faces DB include face locations as well. However, we used our face detector to get all face locations.

# %% [raw]
# def read_face_locations(frame_path:str):
#     person = re.split('/',frame_path)[2]
#     target_frame = re.split('/',frame_path,2)[2]
#     file = 'input/frame_images_DB/{}.labeled_faces.txt'.format(person)
#     with open(file,'r') as f:
#         lines = f.readlines()
#         for line in lines:
#             # frame info
#             frame_path_look = line[:re.search(',',line).start()]
#             if re.split('\W+',target_frame) == re.split('\W+',frame_path_look):
#                 # face locations
#                 x,y,w,h = [int(num) for num in line.split(',')[2:6]]
#                 left = x-w//2
#                 right = x+w//2
#                 bottom = y-h//2
#                 top = y+h//2
#                 face_locations = [top, right, bottom, left]
#                 #face_locations = np.expand_dims(face_locations, axis=0)
#                 print('frame: {} - face_location: {}'.format(frame_path_look, face_locations))
#                 break
#     return [face_locations]
#
# read_face_locations("input/frame_images_DB/Gabi_Zimmer/0/0.1322.jpg")

# %% [markdown]
# ## Loading Datasets

# %%
from utilities.models.facenet1.inception_resnet_v1 import InceptionResNetV1

def facenet_embeddings(X_images, method='array', option=1):
    
    if option == 1:
        # https://sefiks.com/2018/09/03/face-recognition-with-facenet-in-keras/
        # https://github.com/serengil/tensorflow-101/blob/master/model/inception_resnet_v1.py
        facenet_model = InceptionResNetV1()
        #pre-trained weights https://drive.google.com/file/d/1971Xk5RwedbudGgTIrGAL4F7Aifu7id1/view?usp=sharing
        weights_path = "utilities/models/facenet1/facenet_weights.h5"
        facenet_model.load_weights(weights_path)
    elif option ==2:
        # https://machinelearningmastery.com/how-to-develop-a-face-recognition-system-using-facenet-in-keras-and-an-svm-classifier/
        # https://github.com/nyoki-mtl/keras-facenet
        facenet_path = "utilities/models/facenet2/facenet_keras.h5"
        facenet_model = keras.models.load_model(facenet_path, compile=False)
        weights_path = "utilities/models/facenet2/facenet_keras_weights.h5"
        facenet_model.load_weights(weights_path)
        #facenet_model.summary()
        #keras.utils.plot_model(facenet_model, "mini_resnet.png", show_shapes=True)
    print('Face recognizer (facenet{}) was loaded'.format(option))
    
    n_persons, n_examples, h, w, c = X_images.shape
    
    if method == 'list':
        X_embeds = []
        for images in X_images:
            for image in images:
                faces = face_detect.facenet_preprocessing(image)
                face_embeddings = facenet_model.predict(faces)
                face_embeddings = np.transpose(face_embedding)
                X_embeds.append(face_embeddings)
        X_embeds = np.asarray(X_embeds).reshape(n_persons, n_examples, 128, 1)
        
    elif method == 'array':
        X_embeds = np.zeros((n_persons, n_examples, 128, 1), dtype='float64')
        for person in range(n_persons):
            for example in range(n_examples):
                image = X_images[person, example]
                face = face_detect.facenet_preprocessing(image)
                face_embeddings = facenet_model.predict(face)
                face_embeddings = [face_embedding.astype('float32') for face_embedding in face_embeddings]
                face_embeddings = np.transpose(face_embeddings)
                X_embeds[person, example] = face_embeddings
    return X_embeds

# %%
n_persons = 1000
n_samples = 2
train_file_name = "train_npersons_{}_nsamples_{}.pickle".format(n_persons, n_samples)

with open("output/train_test_data/"+train_file_name, "rb") as f:
    (X_images_train, X_embeds_train, y_train, persons_dict_train) = pickle.load(f)
    
X_embeds_fn1_train = facenet_embeddings(X_images_train, option=1)
X_embeds_fn2_train = facenet_embeddings(X_images_train, option=2)
    
n_persons = 100
n_samples = 2
test_file_name = "test_npersons_{}_nsamples_{}.pickle".format(n_persons, n_samples)
    
with open("output/train_test_data/"+test_file_name, "rb") as f:
   (X_images_test, X_embeds_test, y_test, persons_dict_test) =  pickle.load(f)

X_embeds_fn1_test = facenet_embeddings(X_images_test, option=1)
X_embeds_fn2_test = facenet_embeddings(X_images_test, option=2)
# Out:
# Face recognizer (facenet1) was loaded
# Face recognizer (facenet2) was loaded
# Face recognizer (facenet1) was loaded
# Face recognizer (facenet2) was loaded

# %%
print('train: ', [*persons_dict_train])
print('test: ', [*persons_dict_test])
# Out:
# train:  ['Sarah_Weddington', 'James_Kopp', 'Frank_Abagnale_Jr', 'Aleksander_Kwasniewski', 'Gabrielle_Union', 'Peter_Max', 'Theresa_Gattung', 'Wolfgang_Schneiderhan', 'Warren_Buffett', 'Tim_Matheson', 'Aaron_Eckhart', 'Akmal_Taher', 'Takeo_Fukui', 'Martin_Landau', 'Jane_Pauley', 'Ralph_Nader', 'Richard_Harris', 'Patrice_Chereau', 'Caroline_Kennedy', 'Patti_Labelle', 'Adrien_Brody', 'Charlton_Heston', 'Nadia_Petrova', 'Harrison_Ford', 'Tian_Liang', 'Tom_McClintock', 'Gary_Forsee', 'Leticia_Van_de_Putte', 'Nick_Reilly', 'Paul_Krueger', 'William_Bratton', 'Clay_Aiken', 'Zoran_Djindjic', 'Alex_King', 'Ilan_Goldfajn', 'Janis_Ruth_Coulter', 'Maria_Guida', 'Maria_Bello', 'Lance_Bass', 'Marion_Barry', 'Barbara_Becker', 'Nick_Markakis', 'Natalie_Stewart', 'Jane_Fonda', 'Prince_Philippe', 'Zhong_Nanshan', 'Vivica_Fox', 'Elgin_Baylor', 'Dave_Barr', 'Vincent_Gallo', 'James_Traficant', 'Robert_Nardelli', 'Terry_McAuliffe', 'Ricardo_Lopez_Murphy', 'Amy_Brenneman', 'Jason_Biggs', 'Chris_Thomas', 'Catherine_Bell', 'Al_Pacino', 'Alimzhan_Tokhtakhounov', 'Sami_Al-Arian', 'Akhmed_Zakayev', 'Salman_Rushdie', 'Gene_Hackman', 'Andy_Garcia', 'Emma_Thompson', 'Phil_Bredesen', 'Caio_Blat', 'Alexandre_Herchcovitch', 'Adoor_Gopalakarishnan', 'Linda_Dano', 'Rachel_Leigh_Cook', 'Edmund_Stoiber', 'James_Caan', 'Oleg_Romantsev', 'Eve_Ensler', 'Emmit_Smith', 'Eric_Fehr', 'James_Wolfensohn', 'Wayne_Brady', 'Marcos_Milinkovic', 'Roberto_Marinho', 'Nikki_Cascone', 'Naomi_Campbell', 'Sarah_Hughes', 'Carly_Gullickson', 'Franklin_Brown', 'Eliott_Spitzer', 'Laura_Elena_Harring', 'Elena_Dementieva', 'Edward_Albee', 'Cristina_Kirchner', 'Darcy_Regier', 'Tippi_Hedren', 'Habib_Hisham', 'Chris_Bell', 'Mariana_Ohata', 'JC_Chasez', 'Madeleine_Albright', 'Geoffrey_Davis', 'Mark_Wahlberg', 'Gerard_Butler', 'Chick_Hearn', 'Christian_Olsson', 'Linda_Lingle', 'William_Shatner', 'Lena_Katina', 'Jacob_Frenkel', 'Pilar_Montenegro', 'Paul_Hogan', 'Danny_Ainge', 'Randy_Ferbey', 'Tiago_Splitter', 'Imre_Kertasz', 'Lisa_Marie_Presley', 'Christopher_Amolsch', 'George_P_Bush', 'Geno_Auriemma', 'Erskine_Bowles', 'Vadim_Devyatovskiy', 'Ben_Broussard', 'Janet_Napolitano', 'Alex_Penelas', 'Lew_Rywin', 'Ellen_DeGeneres', 'Beatriz_Merino', 'Kyle_Shewfelt', 'Charles_Schumer', 'Rita_Wilson', 'Eric_Lloyd', 'Paul_Patton', 'Gary_Locke', 'Carson_Palmer', 'Ted_Nolan', 'Irene_Kahn', 'Alfonso_Cuaron', 'Norm_Macdonald', 'Fred_Rogers', 'Daniela_Hantuchova', 'Lenny_Wilkens', 'Jaime_Pressly', 'Katie_Harman', 'Thomas_OBrien', 'Elizabeth_Pena', 'Cate_Blanchett', 'Laila_Ali', 'Laurent_Gbagbo', 'Eliane_Karp', 'Natalia_Dmitrieva', 'Paul_Ebert', 'Chris_Columbus', 'Katie_Smith', 'Charlie_Coles', 'Elias_Attallah', 'Larry_Lucchino', 'Alexander_Downer', 'Peter_Fitzgerald', 'Carlos_Salinas', 'Calista_Flockhart', 'Krishna_Bhadur_Mahara', 'Carson_Daly', 'Paula_Radcliffe', 'Lesia_Burlak', 'Emily_Robison', 'Larry_Hagman', 'James_Baker', 'Liu_Mingkang', 'Frederique_van_der_Wal', 'Patricia_Medina', 'Ralph_Friedgen', 'Tino_Martinez', 'Olene_Walker', 'Geoff_Dixon', 'Kathryn_Morris', 'Amram_Mitzna', 'Harald_Ringstorff', 'Lubomir_Zaoralek', 'Xanana_Gusmao', 'Victor_Kraatz', 'Christine_Todd_Whitman', 'Paul_Schrader', 'Ingrid_Betancourt', 'Ahmad_Masood', 'Peter_Mackay', 'Marc_Racicot', 'Terrence_Trammell', 'Clara_Harris', 'Peter_Lundgren', 'Ellen_Pompeo', 'Amelie_Mauresmo', 'Vin_Diesel', 'Sarah_Michelle_Gellar', 'Bertie_Ahern', 'Paula_Abdul', 'Abdullah_Gul', 'Laura_Romero', 'Tanya_Holyk', 'Vladimir_Putin', 'Eric_Bana', 'Benjamin_Netanyahu', 'Claudia_Cardinale', 'Craig_David', 'Andre_Agassi', 'Ciaran_Hinds', 'Daniele_Hypolito', 'George_Clooney', 'Renato_Soru', 'Tina_Brown', 'Lino_Oviedo', 'Liu_Ye', 'Lindsey_Graham', 'Thomas_Manger', 'Phillip_Fulmer', 'Geoff_Hoon', 'Andrew_Fastow', 'Walter_Mondale', 'Paul_Gascoigne', 'Angela_Lansbury', 'Tim_Robbins', 'Lene_Espersen', 'Ion_Tiriac', 'Kostya_Tszyu', 'Alain_Ducasse', 'Otto_Schily', 'Ted_Turner', 'Pascal_Quignard', 'Pak_Gil_Yon', 'Carolina_Barco', 'Nicoletta_Braschi', 'Edward_Flynn', ' ...
# test:  ['Norman_Mailer', 'Pete_Carroll', 'Alexa_Vega', 'Linda_Sanchez', 'Phil_McGraw', 'Candie_Kung', 'Olivier_Boulay', 'Daniel_Scioli', 'Ray_Lewis', 'Rick_Caruso', 'Fran_Drescher', 'Evan_Marriott', 'Catriona_Le_May_Doan', 'Habib_Rizieq', 'Danielle_Spencer', 'Nicanor_Duarte_Frutos', 'Alberto_Ruiz_Gallardon', 'James_Coburn', 'Kenneth_Carlsen', 'Alvaro_Uribe', 'George_Lopez', 'James_Hoffa', 'Angie_Martinez', 'Elmar_Brok', 'Oprah_Winfrey', 'Barry_Diller', 'Ethan_Hawke', 'Jane_Leeves', 'Janez_Drnovsek', 'Chris_Tucker', 'Abbas_Kiarostami', 'George_Plimpton', 'Maria_Soledad_Alvear_Valenzuela', 'Paul_Celluci', 'Paul_Kariya', 'Claire_Danes', 'Mario_Jardel', 'Carla_Tricoli', 'Jalen_Rose', 'Nathan_Lane', 'Paul_Bremer', 'Roger_Suarez', 'Eliza_Dushku', 'Wayne_Newton', 'Paul_Pierce', 'Al_Gore', 'Angelina_Jolie', 'Aly_Wagner', 'Christian_Lacroix', 'Bartosz_Kizierowski', 'Nancy_Sinatra', 'Adam_Ant', 'Peter_Gilmour', 'Olivia_Newton-John', 'Charles_Ingram', 'Christine_Arron', 'Mario_Cipollini', 'Clive_Woodward', 'Richard_Ward', 'Lili_Taylor', 'Vanessa_Williams', 'Rand_Beers', 'Lara_Logan', 'Elodie_Bouchez', 'Nicolas_Cage', 'Evo_Morales', 'Dany_Heatley', 'Kristen_Breitweiser', 'Tessa_Jowell', 'Lee_Byung-woong', 'Salma_Hayek', 'Courtney_Love', 'Laura_Bush', 'Laura_Linney', 'Eric_Rosser', 'Ally_Sheedy', 'Uma_Thurman', 'Compay_Segundo', 'Rachel_Hunter', 'Cindy_Taylor', 'Tom_Osborne', 'Sara_Silverman', 'Claire_Tomalin', 'Adel_Al-Jubeir', 'Laurence_Tribe', 'Janice_Abreu', 'Andy_Warhol', 'Cindy_Klassen', 'Marie-Josee_Croze', 'Jake_Plummer', 'Ray_Wasden', 'Eileen_Coparropa', 'Nestor_Kirchner', 'David_Brinkley', 'Yukio_Hatoyama', 'Frank_Hsieh', 'Laurent_Woulzy', 'Frank_Murkowski', 'Erin_Runnion', 'Ivana_Trump']

# %%
images_shape = X_images_train[0][0].shape
embeds_shape = X_embeds_train[0][0].shape

print('- images shape: {} - embeddings shape: {}'.format(images_shape, embeds_shape))
# Out:
# - images shape: (100, 100, 3) - embeddings shape: (128, 1)

# %%
train_embeds_shape = X_embeds_fn1_train[0][0].shape
test_embeds_shape = X_embeds_fn1_test[0][0].shape

print('facenet1: - train embeddings shape: {} - test embeddings shape: {}'.format(train_embeds_shape, 
                                                                                  test_embeds_shape))

train_embeds_shape = X_embeds_fn2_train[0][0].shape
test_embeds_shape = X_embeds_fn2_test[0][0].shape

print('facenet2: - train embeddings shape: {} - test embeddings shape: {}'.format(train_embeds_shape, 
                                                                                  test_embeds_shape))
# Out:
# facenet1: - train embeddings shape: (128, 1) - test embeddings shape: (128, 1)
# facenet2: - train embeddings shape: (128, 1) - test embeddings shape: (128, 1)

# %% [markdown]
# ## Get Functions

# %% [markdown]
# ### Get Pairs

# %%
def get_pairs(batch_size=None, train=True, embed=False, normalize=False, flatten=False,
              flip_same=False, do_shuffle=True, embed_option=None):
    """ Create batch size pairs (first half: different persons - second half: same persons)"""
    
    # select data
    if train:
        if embed:
            if embed_option == 'face_recognition' or embed_option is None:  
                X =  X_embeds_train
            elif embed_option == 'facenet1':
                X =  X_embeds_fn1_train
            elif embed_option == 'facenet2':
                X =  X_embeds_fn2_train
                
            flip_same = False
            normalize = False
            flatten = False
        else:
            X = X_images_train
    else:
        if embed:
            if embed_option == 'face_recognition' or embed_option is None:  
                X =  X_embeds_test
            elif embed_option == 'facenet1':
                X =  X_embeds_fn1_test
            elif embed_option == 'facenet2':
                X =  X_embeds_fn2_test

            flip_same = False
            normalize=False
        else:
            X = X_images_test

    # if batch is not defined then take all examples (one for each person)
    if batch_size == None:
        batch_size = X.shape[0]
        
    # extract shape parameters
    if len(X.shape) == 5:
        n_persons, n_examples, h, w, n_channels = X.shape
        shape = (batch_size, h, w, n_channels)
        dtype = int
    else: 
        n_persons, n_examples, h, n_channels = X.shape
        shape = (batch_size, h, n_channels)
        dtype = float
        
    assert n_persons >= batch_size, "n_persons ({}) should be >= batch_size ({})".format(n_persons, 
                                                                                         batch_size)
    # sample diffirent persons (without replacement) based on the batch size
    persons = np.random.choice(n_persons, size=(batch_size,),replace=False)
    # initialize a pairs of a batch size
    pairs = [np.zeros(shape, dtype=dtype) for i in range(2)] # images int !!!!!!!!!
    # initialize targets
    targets = np.zeros((batch_size,))
    # second half is when the person is the same! 
    targets[batch_size//2:] = 1
    
    # loop through persons
    for i in range(batch_size):
        person_1 = persons[i]
        # sample two different examples from n_examples (without replacement)
        idx_1, idx_2 = np.random.choice(n_examples, size=(2,), replace=False)
        # save 1st example for this person 
        pairs[0][i] = X[person_1, idx_1]
        # check if we passed half of the batch size
        if i >= batch_size//2:
            # if true then take the same person again!
            person_2 = person_1
            if flip_same:
                pairs[1][i] = np.flip(X[person_2, idx_2],axis=1)
            else:
                pairs[1][i] = X[person_2, idx_2]
        else:
            # else take another person
            person_2 = (person_1 + np.random.randint(1,n_persons)) % n_persons
            pairs[1][i] = X[person_2, idx_2]
        
    if normalize:
        pairs[0] = pairs[0]/255
        pairs[1] = pairs[1]/255
        
    # flatten
    if flatten:
        shape = (batch_size, h*w*n_channels)
        pairs[0] = np.reshape(pairs[0], shape)
        pairs[1] = np.reshape(pairs[1], shape)
        
    # shuffle
    if do_shuffle:
        pairs[0], pairs[1], targets = shuffle(pairs[0], pairs[1], targets)
    
    return pairs, targets

# %% [markdown]
# ### Get Oneshot

# %%
def get_oneshot(N, train=False, embed=False, person=None, report=False, 
                flip_same=False, normalize=False, do_shuffle=True, embed_option=None):
    """ Create pairs of test image """
        
    # select data
    if train:
        persons_dict = persons_dict_train
        if embed:
            if embed_option == 'face_recognition' or embed_option is None: 
                X =  X_embeds_train
            elif embed_option == 'facenet1':
                X =  X_embeds_fn1_train
            elif embed_option == 'facenet2':
                X =  X_embeds_fn2_train
            flip_same = False
            normalize=False
        else:
            X = X_images_train
    else:
        persons_dict = persons_dict_test
        if embed:
            if embed_option == 'face_recognition' or embed_option is None: 
                X =  X_embeds_test
            elif embed_option == 'facenet1':
                X =  X_embeds_fn1_test
            elif embed_option == 'facenet2':
                X =  X_embeds_fn2_test
            flip_same = False
            normalize=False
        else:
            X = X_images_test
        
    # extract shape parameters
    if len(X.shape) == 5:
        n_persons, n_examples, h, w, n_channels = X.shape
        #shape = (N, h, w, n_channels)
    else: 
        n_persons, n_examples, h, n_channels = X.shape
        #shape = (N, h, n_channels)
        
    assert n_persons >= N, "n_persons ({}) should be >= N ({})".format(n_persons, N)
    # sample persons N-times (based on the N-Way) (without replacement - difference persons)
    persons = np.random.choice(n_persons, size=(N,), replace=False)
    if report: print('selected persons:', persons)
    # sample N times examples (an example for each person)
    examples = np.random.randint(0, n_examples, size=(N,))
    if report: print('selected examples:', examples)
    
    # check if a person was specified
    if person is not None:
        # find specific person index as a true person
        true_person = [*persons_dict].index(person)
        # check if true person is not in the list
        if true_person in persons:
            # if in the list, then find its key
            true_person_key = np.where(persons==true_person)[0][0]
        # if not in the list then add as first
        else:
            persons[0] = true_person
            true_person_key = 0
    else:
        # take the first person as a true person
        true_person = persons[0]
        true_person_key = 0 
    if report: print('selected person: name:{}, index:{}, key:{}'.format(person, true_person, true_person_key))
    if report: print('selected persons:', persons)
    
    # sample two different examples from n_examples (without replacement)
    ex1, ex2 = np.random.choice(n_examples, size=(2,), replace=False)
    if report: print('selected true person examples:', ex1, ex2)
    # copy true person (1st sampled example) image N times
    test_image = np.asarray([X[true_person, ex1]]*N)#.reshape(N, w, h, n_channels)
    # copy persons images (sampled exampled - including true person)
    support_set = X[persons, examples, :, :]
    if report: print("test images (true person N times) and support images (inc. 1 true person) were created")
    
    # change the example for the true person to the second one (assures diff examples!)
    if not embed and flip_same:
        support_set[true_person_key] = np.flip(X[true_person, ex2],axis=1)
    else:
        support_set[true_person_key] = X[true_person, ex2]
    
    if normalize:
        if embed:
            normalizer = Normalizer(norm="L2") # does not need fit
            test_image = normalizer.trasform(test_image) 
            support_set = normalizer.trasform(support_set)
        else:
            test_image = test_image/255
            support_set = support_set/255
        
    # create target values
    targets = np.zeros((N,))
    
    # edit test image label
    targets[true_person_key] = 1
    
    # shuffle
    if do_shuffle:
        targets, test_image, support_set = shuffle(targets, test_image, support_set)
    
    # create pair of images
    pairs = [test_image, support_set]
    
    return pairs, targets

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### Functions

# %%
def concat_images(X, targets):
    """Concatenates a bunch of images into a big matrix for plotting purposes."""
    n_examples, h, w, n_channels = X.shape
    n = np.ceil(np.sqrt(n_examples)).astype("int8")
    img = np.ones((n*w, n*h, n_channels)).astype("int8")*255
    x = 0
    y = 0
    for example in range(n_examples):
        img[x*w:(x+1)*w,y*h:(y+1)*h,:] = X[example]
        cv2.putText(img[x*w:(x+1)*w,y*h:(y+1)*h,:], '{}'.format(int(targets[example])), (50,50), 
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)
        y += 1
        if y >= n:
            y = 0
            x += 1
    return img


def show_Nway(pairs, targets):
    fig,(ax1,ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10,200))
    ax1.imshow(pairs[0][1])
    img = concat_images(pairs[1], targets)
    ax1.get_yaxis().set_visible(False)
    ax1.get_xaxis().set_visible(False)
    ax2.imshow(img)
    plt.xticks([])
    plt.yticks([])
    plt.show()
    
def show_pairs(example_pairs, example_targets, deflatten=False):
    n = len(example_pairs[0])
    fig, axs = plt.subplots(nrows=n, ncols=2, figsize=(5,n*2))
    for row in range(n):
        for col in range(2):
            if deflatten:
                axs[row,col].imshow(np.reshape(example_pairs[col][row], (100,100,3)))#, cmap='binary')
            else:
                axs[row,col].imshow(example_pairs[col][row])
            if col == 1:
                axs[row,col].annotate(xy=(100//2,100//2), s=str(int(example_targets[row])), c='w', fontsize=18)
            axs[row,col].set_xticks([])
            axs[row,col].set_yticks([])
    plt.subplots_adjust(wspace=0, hspace=0)
    plt.show()

# %% [markdown]
# ### Example 1: show pairs

# %%
example_pairs, example_targets = get_pairs(batch_size=32, train=True, embed=False, flatten=True)

# %%
show_pairs(example_pairs, example_targets, deflatten=True)

# %% [markdown]
# ### Example 2: show oneshot

# %%
example_pairs, example_targets = get_oneshot(N=9, train=True, embed=False, normalize=False)

# %%
show_Nway(example_pairs, example_targets)

# %%
show_pairs(example_pairs, example_targets)

# %% [markdown]
# ##  Test Oneshot Model

# %%
def test_oneshot(model, N, k, train=False, embed=False, normalize=False, do_shuffle=True, verbose=False,
                 combine=False, embed_option=None):
    """ Test average one-shot learning accuracy based on N-way
    Arguments:
    - model: Siamese Network
    - N: Number of pairs (at which only one pair matches) to be tested in each one prediction test
    - k: Number of prediction tests to perform
    - train: Boolean, True if training and False if testing
    - verbose: Boolean.
    """
    # initialize number of correct predictions
    n_correct = 0
    for i in range(k):
        inputs, targets = get_oneshot(N, train, embed=embed, normalize=normalize, do_shuffle=do_shuffle, 
                                      embed_option=embed_option)
        if combine:
             inputs = combine_pairs(inputs)
        probs = model.predict(inputs)
        #print(probs)
        if np.argmax(probs) == np.argmax(targets):
            n_correct += 1
    percent_correct = n_correct/k
    if verbose:
        text = "train" if train else "test"
        print("[{}] oneshot learning accuracy: {}% (evaluated by {} N-Way for {} times)".format(text, 
                                                                            int(100*percent_correct), 
                                                                                            N, k))
    return percent_correct

# %% [markdown]
# ## Siamese Model (Pairs)

# %%
def init_weights(shape, dtype=None, name=None):
    return np.random.normal(loc=0.0, scale=1e-2, size=shape)

def init_bias(shape, dtype=None, name=None):
    return np.random.normal(loc=0.5, scale=1e-2, size=shape)

def get_conv(input_shape, name=None, model=None, app='images', learn='before_l2'):
    if app == 'images':
        input_layer = keras.Input(input_shape, name='{}_input_layer'.format(name))
        if model == None:
            model = keras.Sequential(name='siamese_{}'.format(app))
            model.add(layers.Conv2D(64, (10,10), activation='relu', kernel_regularizer=l2(2e-4), input_shape=input_shape,
                                kernel_initializer=init_weights, bias_initializer=init_bias))
            model.add(layers.MaxPooling2D(strides=2))
            model.add(layers.Conv2D(128, (7,7), activation='relu', kernel_regularizer=l2(2e-4),
                                kernel_initializer=init_weights, bias_initializer=init_bias))
            model.add(layers.MaxPooling2D(strides=2))
            model.add(layers.Conv2D(128, (4,4), activation='relu', kernel_regularizer=l2(2e-4),
                                kernel_initializer=init_weights, bias_initializer=init_bias))
            model.add(layers.MaxPooling2D(strides=2))
            model.add(layers.Conv2D(256, (4,4), activation='relu', kernel_regularizer=l2(2e-4),
                                kernel_initializer=init_weights, bias_initializer=init_bias))
            model.add(layers.Flatten())
            model.add(layers.Dense(4096, activation='sigmoid', kernel_regularizer=l2(2e-4),
                                   kernel_initializer=init_weights, bias_initializer=init_bias))
            encoded = model(input_layer)
            return encoded, input_layer, model
        else:
            encoded = model(input_layer)
            return encoded, input_layer
    elif app == 'embeds':
        input_layer = keras.Input(input_shape, name='{}_input_layer'.format(name))
        if model == None:
            model = keras.Sequential(name='siamese_{}'.format(app))
            model.add(layers.Flatten())
            if learn == 'before_l2' or learn == 'before_after_l2':
                model.add(layers.Dense(256, activation='relu'))
            encoded = model(input_layer)
            return encoded, input_layer, model
        else:
            encoded = model(input_layer)
            return encoded, input_layer
        
    
def init_siamse_model(input_shape, app='images', learn='before_l2'):
    
    if app=='images' and (learn == 'before_l2' or learn == 'only_l2'):
        print("When app='images', learn='before_l2 and learn='only_l2' give exactly the same model")
        print(" - in both cases, a learning layers has to be added before calculating l2 distance")
    
    # encode
    left_encoded, left_input, model = get_conv(input_shape, name="left", app=app, learn=learn)
    right_encoded, right_input = get_conv(input_shape, name="right", model=model, app=app)
    
    # compute the absolute difference (cosine loss function)
    L1_layer = layers.Lambda(lambda tensors: K.abs(tensors[0] - tensors[1]), name='abs_diff')
    L1_distance = L1_layer([left_encoded, right_encoded])
    
    if learn == 'after_l2' or learn == 'before_after_l2':
        learn_layer = layers.Dense(64, activation='sigmoid', kernel_regularizer=l2(2e-4),
                                   kernel_initializer=init_weights, bias_initializer=init_bias)(L1_distance)
        learn_layer = layers.Dense(32, activation='sigmoid', kernel_regularizer=l2(2e-4),
                                   kernel_initializer=init_weights, bias_initializer=init_bias)(learn_layer)
        y = layers.Dense(1, activation='sigmoid', bias_initializer=init_bias, name='ouput')(learn_layer)
    
    elif learn == 'only_l2' or learn == 'before_l2':
        y = layers.Dense(1, activation='sigmoid', bias_initializer=init_bias, name='ouput')(L1_distance)

    # siamese network
    siamese_net = keras.Model(inputs=[left_input, right_input], outputs=y)
    return siamese_net

# %%
optimizer = keras.optimizers.Adam(lr=0.00006)

# %% [markdown]
# ### Images Model

# %%
# learn: only_l2 (same as before_l2)
images_model_only_l2 = init_siamse_model((images_shape), app='images', learn='only_l2')
images_model_only_l2.compile(loss="binary_crossentropy", optimizer=optimizer, metrics='accuracy')
images_model_only_l2.save_weights("output/siamese_model/images_only_l2/init_weights.h5")

# learn: after_l2 (same as before_after_l2)
images_model_after_l2 = init_siamse_model((images_shape), app='images', learn='after_l2')
images_model_after_l2.compile(loss="binary_crossentropy", optimizer=optimizer, metrics='accuracy')
images_model_after_l2.save_weights("output/siamese_model/images_after_l2/init_weights.h5")
# Out:
# When app='images', learn='before_l2 and learn='only_l2' give exactly the same model
#  - in both cases, a learning layers has to be added before calculating l2 distance

# %%
images_model_only_l2.summary()
# Out:
# Model: "model_10"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# left_input_layer (InputLayer)   [(None, 100, 100, 3) 0
# __________________________________________________________________________________________________
# right_input_layer (InputLayer)  [(None, 100, 100, 3) 0
# __________________________________________________________________________________________________
# siamese_images (Sequential)     (None, 4096)         27426112    left_input_layer[0][0]
#                                                                  right_input_layer[0][0]
# __________________________________________________________________________________________________
# abs_diff (Lambda)               (None, 4096)         0           siamese_images[1][0]
#                                                                  siamese_images[2][0]
# __________________________________________________________________________________________________
# ouput (Dense)                   (None, 1)            4097        abs_diff[0][0]
# ==================================================================================================
# Total params: 27,430,209
# Trainable params: 27,430,209
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# requires: 1. pip install pydot and graphviz - 2. sudo apt-get install graphviz
keras.utils.plot_model(images_model_only_l2, show_shapes=True)

# %%
keras.utils.plot_model(images_model_after_l2, show_shapes=True)

# %% [markdown]
# ### Embeds Model

# %%
# learn: only_l2
embeds_model_only_l2 = init_siamse_model((embeds_shape), app='embeds', learn='only_l2')
embeds_model_only_l2.compile(loss="binary_crossentropy", optimizer=optimizer, metrics='accuracy')
embeds_model_only_l2.save_weights("output/siamese_model/embeds_only_l2/init_weights.h5")

# learn: before_l2
embeds_model_before_l2 = init_siamse_model((embeds_shape), app='embeds', learn='before_l2')
embeds_model_before_l2.compile(loss="binary_crossentropy",optimizer=optimizer, metrics='accuracy')
embeds_model_before_l2.save_weights("output/siamese_model/embeds_before_l2/init_weights.h5")

# learn: after_l2
embeds_model_after_l2 = init_siamse_model((embeds_shape), app='embeds', learn='after_l2')
embeds_model_after_l2.compile(loss="binary_crossentropy",optimizer=optimizer, metrics='accuracy')
embeds_model_after_l2.save_weights("output/siamese_model/embeds_after_l2/init_weights.h5")

# learn: before_after_l2
embeds_model_before_after_l2 = init_siamse_model((embeds_shape), app='embeds', learn='before_after_l2')
embeds_model_before_after_l2.compile(loss="binary_crossentropy",optimizer=optimizer, metrics='accuracy')
embeds_model_before_after_l2.save_weights("output/siamese_model/embeds_before_after_l2/init_weights.h5")

# %%
embeds_model_after_l2.summary()
# Out:
# Model: "model_18"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# left_input_layer (InputLayer)   [(None, 128, 1)]     0
# __________________________________________________________________________________________________
# right_input_layer (InputLayer)  [(None, 128, 1)]     0
# __________________________________________________________________________________________________
# siamese_embeds (Sequential)     (None, 128)          0           left_input_layer[0][0]
#                                                                  right_input_layer[0][0]
# __________________________________________________________________________________________________
# abs_diff (Lambda)               (None, 128)          0           siamese_embeds[0][0]
#                                                                  siamese_embeds[1][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 64)           8256        abs_diff[0][0]
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 32)           2080        dense_24[0][0]
# __________________________________________________________________________________________________
# ouput (Dense)                   (None, 1)            33          dense_25[0][0]
# ==================================================================================================
# Total params: 10,369
# Trainable params: 10,369
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(embeds_model_after_l2, show_shapes=True)

# %% [markdown]
# ## Siamese Network Training

# %%
def siamese_train(epochs=10, batch_size=64, train_type='batch', save_weights='final', eval_freq=2,
                  n_way=10, n_test=10, embed=False, normalize=False, do_shuffle=True, plot=True, 
                  embed_option='face_recognition', learn=None):
    
    test_batch_size = X_images_test.shape[0] # should not be higher than the n_persons in test data
    nway_best = 0
    test_best = 0
    
    model_path = "output/siamese_model/"
    results = {'train_loss':[], 'train_acc':[],
               'test_loss':[], 'test_acc':[],
               'n_way_train_acc':[], 'n_way_test_acc':[]}
    
    print("starting oneshot training (evaluated by {} N-Way for {} times):".format(n_way, n_test))
    start_time = time.time()
    
    if embed:
        if learn == None or learn == 'only_l2':
            model = embeds_model_only_l2
            model_name = "embeds_only_l2"
        elif learn == 'before_l2': 
            model = embeds_model_before_l2
            model_name = "embeds_before_l2"
        elif learn == 'after_l2':
            model = embeds_model_after_l2
            model_name = "embeds_after_l2"
        elif learn == 'before_after_l2':
            model = embeds_model_before_after_l2
            model_name = "embeds_before_after_l2"
        text = "embeds"
    else:
        if learn == None or learn == 'only_l2' or learn == 'before_l2':
            model = images_model_only_l2
            model_name = "images_only_l2"
        elif learn == 'after_l2' or learn == 'before_after_l2':
            model = images_model_after_l2
            model_name = "images_after_l2"
        text = "images"
    model.load_weights(os.path.join(model_path, model_name, "init_weights.h5"))
        
        
    if normalize:
        text = 'nor_'+text
    text = text+'_bs{}_ep{}'.format(batch_size,epochs)
    
    if train_type == 'batch':
        text = 'batch_'+text
        n_persons = X_images_train.shape[0] #or X_embeds_train.shape[0]
        iters_per_epoch = n_persons//batch_size # equivalent to 1 epoch
        iters = epochs*iters_per_epoch
        print(" - epochs: {} (eq.iters: {}) - eval freq: {} - batch_size: {}".format(epochs,
                                                                                     iters,
                                                                                     eval_freq, 
                                                                                     batch_size))
        eval_freq = eval_freq*iters_per_epoch
        epochs = iters
    elif train_type == 'epoch':
        text = 'epoch_'+text
        iters_per_epoch = 1
        print(" - epochs: {} - eval freq: {} - batch_size: {}".format(epochs, eval_freq, batch_size))
        
    text = embed_option+'_'+text
        
    assert n_way <= test_batch_size, "n_way should be <= n_persons in test data"
    assert epochs >= eval_freq, "epcohs should be >= eval_freq"
    
    for epoch in range(1, epochs+1):        
            
        if train_type == 'epoch':
            X_train, y_train = get_pairs(None, train=True, embed=embed, normalize=normalize, 
                                         do_shuffle=do_shuffle, embed_option=embed_option)
            outputs = model.fit(X_train, y_train, batch_size, epochs=1, verbose=0, shuffle=False)
            outputs = [outputs.history['loss'][0],outputs.history['accuracy'][0]]
            
        elif train_type == 'batch':
            X_train, y_train = get_pairs(batch_size, train=True, embed=embed, normalize=normalize, 
                                         do_shuffle=do_shuffle, embed_option=embed_option)   
            
            outputs = model.train_on_batch(X_train, y_train)
            
        if save_weights == 'step':
            if train_type == 'batch': epoch_num = epoch//iters_per_epoch
            else: epoch_num = epoch
            model.save_weights(os.path.join(model_path, model_name, "{}_epoch_{}.h5".format(text,epoch_num)))
        
        if epoch % eval_freq == 0:
            
            results['train_loss'].append(outputs[0])
            results['train_acc'].append(outputs[1])

            X_test, y_test = get_pairs(test_batch_size, train=False, embed=embed, 
                                     normalize=normalize, do_shuffle=do_shuffle, embed_option=embed_option)
            outputs = model.evaluate(X_test, y_test, batch_size=test_batch_size, verbose=0)

            results['test_loss'].append(outputs[0])
            results['test_acc'].append(outputs[1])
            
            train_loss = round(results['train_loss'][-1],2)
            train_acc = round(results['train_acc'][-1],2)
            test_loss = round(results['test_loss'][-1],2)
            test_acc = round(results['test_acc'][-1],2)
            
            print("----------------------------------------------------------------------------------------")
            process_time = round((time.time()-start_time) / 60.0, 1)
            print("[{}mins] epoch: {} | train loss:{} | train acc:{} |".format(process_time, 
                                                                        epoch//iters_per_epoch, 
                                                                        train_loss, train_acc))
            print("                     | test loss: {} | test acc: {} |".format(test_loss,test_acc))
            
            nway_train_acc = test_oneshot(model, n_way, n_test, train=True, embed=embed, 
                                          normalize=normalize, do_shuffle=do_shuffle, 
                                          embed_option=embed_option)
            nway_test_acc = test_oneshot(model, n_way, n_test, train=False, embed=embed, 
                                         normalize=normalize, do_shuffle=do_shuffle, 
                                         embed_option=embed_option)

            print("                     | N-Way train acc:{} | N-Way test acc:{}".format(nway_train_acc, 
                                                                                         nway_test_acc))
            results['n_way_train_acc'].append(nway_train_acc)
            results['n_way_test_acc'].append(nway_test_acc)
            

            if nway_test_acc > nway_best:
                print("          | best N-Way test acc: current={} | previous={})".format(nway_test_acc,
                                                                                          nway_best))
                nway_best = nway_test_acc
                model.save_weights(os.path.join(model_path, model_name, "{}_nway_best.h5".format(text)))
                
            if test_acc > test_best:
                print("          | best test acc: current={} | previous={})".format(test_acc, test_best))
                test_best = test_acc
                model.save_weights(os.path.join(model_path, model_name, "{}_test_best.h5".format(text)))
    
    if plot:
        plt.plot(results['train_loss'], '-r', label='Train.loss')
        plt.plot(results['train_acc'], '-g', label='Train.Acc')
        plt.plot(results['test_loss'], ':r', label='Test.loss')
        plt.plot(results['test_acc'], ':g', label='Test.Acc')
        plt.plot(results['n_way_train_acc'], '-b', label='N-way.Train.Acc')
        plt.plot(results['n_way_test_acc'], ':b', label='N-way.Test.Acc')
        plt.ylim(0,1.1)
        plt.legend(bbox_to_anchor=(1, 1))
                
    if save_weights == 'final':
        model.save_weights(os.path.join(model_path, model_name, "{}_final.h5".format(text)))
    
    with open(os.path.join(model_path, model_name, "results", "{}_results.pickle".format(text)), "wb") as f:
        pickle.dump(results,f)
                  
    #return results

# %% [markdown]
# ## Learn Only L2
#     - without normalization

# %% [markdown]
# ### embed_option: 'face_recognition'

# %%
siamese_train(epochs=600, batch_size=256, train_type='batch', eval_freq=40, n_way=10, n_test=100, 
              embed=True, normalize=False, do_shuffle=True, 
              embed_option='face_recognition', learn='only_l2')
# Out:
# starting oneshot training (evaluated by 10 N-Way for 100 times):
#  - epochs: 600 (eq.iters: 1800) - eval freq: 40 - batch_size: 256
# ----------------------------------------------------------------------------------------
# [0.0mins] epoch: 40 | train loss:0.71 | train acc:0.5 |
#                    | test loss: 0.72 | test acc: 0.5 |
#                    | N-Way train acc:0.18 | N-Way test acc:0.05
#           | best N-Way train acc: current=0.05 | previous=0)
#           | best test acc: current=0.5 | previous=0)
# ----------------------------------------------------------------------------------------
# [0.1mins] epoch: 80 | train loss:0.71 | train acc:0.5 |
#                    | test loss: 0.71 | test acc: 0.5 |
#                    | N-Way train acc:0.3 | N-Way test acc:0.19
#           | best N-Way train acc: current=0.19 | previous=0.05)
# ----------------------------------------------------------------------------------------
# [0.3mins] epoch: 120 | train loss:0.7 | train acc:0.5 |
#                    | test loss: 0.7 | test acc: 0.5 |
#                    | N-Way train acc:0.35 | N-Way test acc:0.39
#           | best N-Way train acc: current=0.39 | previous=0.19)
# ----------------------------------------------------------------------------------------
# [0.4mins] epoch: 160 | train loss:0.69 | train acc:0.5 |
#                    | test loss: 0.69 | test acc: 0.5 |
#                    | N-Way train acc:0.49 | N-Way test acc:0.46
#           | best N-Way train acc: current=0.46 | previous=0.39)
# ----------------------------------------------------------------------------------------
# [0.5mins] epoch: 200 | train loss:0.68 | train acc:0.5 |
#                    | test loss: 0.68 | test acc: 0.5 |
#                    | N-Way train acc:0.69 | N-Way test acc:0.66
#           | best N-Way train acc: current=0.66 | previous=0.46)
# ----------------------------------------------------------------------------------------
# [0.7mins] epoch: 240 | train loss:0.67 | train acc:0.5 |
#                    | test loss: 0.68 | test acc: 0.5 |
#                    | N-Way train acc:0.69 | N-Way test acc:0.61
# ----------------------------------------------------------------------------------------
# [0.8mins] epoch: 280 | train loss:0.67 | train acc:0.5 |
#                    | test loss: 0.67 | test acc: 0.5 |
#                    | N-Way train acc:0.86 | N-Way test acc:0.76
#           | best N-Way train acc: current=0.76 | previous=0.66)
# ----------------------------------------------------------------------------------------
# [0.9mins] epoch: 320 | train loss:0.66 | train acc:0.51 |
#                    | test loss: 0.67 | test acc: 0.51 |
#                    | N-Way train acc:0.82 | N-Way test acc:0.86
#           | best N-Way train acc: current=0.86 | previous=0.76)
#           | best test acc: current=0.51 | previous=0.5)
# ----------------------------------------------------------------------------------------
# [1.0mins] epoch: 360 | train loss:0.66 | train acc:0.54 |
#                    | test loss: 0.66 | test acc: 0.53 |
#                    | N-Way train acc:0.84 | N-Way test acc:0.9
#           | best N-Way train acc: current=0.9 | previous=0.86)
#           | best test acc: current=0.53 | previous=0.51)
# ----------------------------------------------------------------------------------------
# [1.1mins] epoch: 400 | train loss:0.65 | train acc:0.62 |
#                    | test loss: 0.65 | test acc: 0.56 |
#                    | N-Way train acc:0.9 | N-Way test acc:0.85
#           | best test acc: current=0.56 | previous=0.53)
# ----------------------------------------------------------------------------------------
# [1.3mins] epoch: 440 | train loss:0.64 | train acc:0.68 |
#                    | test loss: 0.64 | test acc: 0.67 |
#                    | N-Way train acc:0.93 | N-Way test acc:0.88
#           | best test acc: current=0.67 | previous=0.56)
# ----------------------------------------------------------------------------------------
# [1.4mins] epoch: 480 | train loss:0.64 | train acc:0.77 |
#                    | test loss: 0.64 | test acc: 0.76 |
#                    | N-Way train acc:0.92 | N-Way test acc:0.88
#           | best test acc: current=0.76 | previous=0.67)
# ----------------------------------------------------------------------------------------
# [1.5mins] epoch: 520 | train loss:0.63 | train acc:0.85 |
#                    | test loss: 0.63 | test acc: 0.84 |
#                    | N-Way train acc:0.89 | N-Way test acc:0.86
#           | best test acc: current=0.84 | previous=0.76)
# ----------------------------------------------------------------------------------------
# [1.7mins] epoch: 560 | train loss:0.63 | train acc:0.92 |
#                    | test loss: 0.63 | test acc: 0.88 |
#                    | N-Way train acc:0.94 | N-Way test acc:0.88
#           | best test acc: current=0.88 | previous=0.84)
# ----------------------------------------------------------------------------------------
# [1.8mins] epoch: 600 | train loss:0.63 | train acc:0.93 |
#                    | test loss: 0.62 | test acc: 0.95 |
#                    | N-Way train acc:0.92 | N-Way test acc:0.95
#           | best N-Way train acc: current=0.95 | previous=0.9)
#           | best test acc: current=0.95 | previous=0.88)

# %%
siamese_train(epochs=600, batch_size=256, train_type='epoch', eval_freq=40, n_way=10, n_test=100, 
              embed=True, normalize=False, do_shuffle=True, 
              embed_option='face_recognition', learn='only_l2')
# Out:
# starting oneshot training (evaluated by 10 N-Way for 100 times):
#  - epochs: 600 - eval freq: 40 - batch_size: 256
# ----------------------------------------------------------------------------------------
# [0.0mins] epoch: 40 | train loss:0.71 | train acc:0.5 |
#                    | test loss: 0.72 | test acc: 0.5 |
#                    | N-Way train acc:0.11 | N-Way test acc:0.04
#           | best N-Way train acc: current=0.04 | previous=0)
#           | best test acc: current=0.5 | previous=0)
# ----------------------------------------------------------------------------------------
# [0.2mins] epoch: 80 | train loss:0.7 | train acc:0.5 |
#                    | test loss: 0.7 | test acc: 0.5 |
#                    | N-Way train acc:0.32 | N-Way test acc:0.26
#           | best N-Way train acc: current=0.26 | previous=0.04)
# ----------------------------------------------------------------------------------------
# [0.3mins] epoch: 120 | train loss:0.69 | train acc:0.5 |
#                    | test loss: 0.69 | test acc: 0.5 |
#                    | N-Way train acc:0.51 | N-Way test acc:0.54
#           | best N-Way train acc: current=0.54 | previous=0.26)
# ----------------------------------------------------------------------------------------
# [0.5mins] epoch: 160 | train loss:0.68 | train acc:0.5 |
#                    | test loss: 0.67 | test acc: 0.5 |
#                    | N-Way train acc:0.63 | N-Way test acc:0.68
#           | best N-Way train acc: current=0.68 | previous=0.54)
# ----------------------------------------------------------------------------------------
# [0.6mins] epoch: 200 | train loss:0.67 | train acc:0.5 |
#                    | test loss: 0.67 | test acc: 0.5 |
#                    | N-Way train acc:0.78 | N-Way test acc:0.82
#           | best N-Way train acc: current=0.82 | previous=0.68)
# ----------------------------------------------------------------------------------------
# [0.7mins] epoch: 240 | train loss:0.66 | train acc:0.51 |
#                    | test loss: 0.67 | test acc: 0.51 |
#                    | N-Way train acc:0.81 | N-Way test acc:0.85
#           | best N-Way train acc: current=0.85 | previous=0.82)
#           | best test acc: current=0.51 | previous=0.5)
# ----------------------------------------------------------------------------------------
# [0.9mins] epoch: 280 | train loss:0.65 | train acc:0.55 |
#                    | test loss: 0.66 | test acc: 0.56 |
#                    | N-Way train acc:0.9 | N-Way test acc:0.83
#           | best test acc: current=0.56 | previous=0.51)
# ----------------------------------------------------------------------------------------
# [1.0mins] epoch: 320 | train loss:0.65 | train acc:0.65 |
#                    | test loss: 0.65 | test acc: 0.66 |
#                    | N-Way train acc:0.86 | N-Way test acc:0.96
#           | best N-Way train acc: current=0.96 | previous=0.85)
#           | best test acc: current=0.66 | previous=0.56)
# ----------------------------------------------------------------------------------------
# [1.2mins] epoch: 360 | train loss:0.64 | train acc:0.76 |
#                    | test loss: 0.64 | test acc: 0.76 |
#                    | N-Way train acc:0.91 | N-Way test acc:0.85
#           | best test acc: current=0.76 | previous=0.66)
# ----------------------------------------------------------------------------------------
# [1.3mins] epoch: 400 | train loss:0.63 | train acc:0.87 |
#                    | test loss: 0.64 | test acc: 0.86 |
#                    | N-Way train acc:0.9 | N-Way test acc:0.9
#           | best test acc: current=0.86 | previous=0.76)
# ----------------------------------------------------------------------------------------
# [1.5mins] epoch: 440 | train loss:0.63 | train acc:0.91 |
#                    | test loss: 0.62 | test acc: 0.95 |
#                    | N-Way train acc:0.92 | N-Way test acc:0.94
#           | best test acc: current=0.95 | previous=0.86)
# ----------------------------------------------------------------------------------------
# [1.6mins] epoch: 480 | train loss:0.62 | train acc:0.93 |
#                    | test loss: 0.63 | test acc: 0.93 |
#                    | N-Way train acc:0.91 | N-Way test acc:0.93
# ----------------------------------------------------------------------------------------
# [1.7mins] epoch: 520 | train loss:0.62 | train acc:0.92 |
#                    | test loss: 0.62 | test acc: 0.9 |
#                    | N-Way train acc:0.94 | N-Way test acc:0.94
# ----------------------------------------------------------------------------------------
# [1.9mins] epoch: 560 | train loss:0.61 | train acc:0.9 |
#                    | test loss: 0.62 | test acc: 0.92 |
#                    | N-Way train acc:0.92 | N-Way test acc:0.91
# ----------------------------------------------------------------------------------------
# [2.0mins] epoch: 600 | train loss:0.61 | train acc:0.88 |
#                    | test loss: 0.61 | test acc: 0.87 |
#                    | N-Way train acc:0.92 | N-Way test acc:0.93

# %% [markdown]
# ### embed_option: 'facenet1'

# %%
siamese_train(epochs=600, batch_size=256, train_type='batch', eval_freq=40, n_way=10, n_test=100, 
              embed=True, normalize=False, do_shuffle=True, 
              embed_option='facenet1', learn='only_l2')
# Out:
# starting oneshot training (evaluated by 10 N-Way for 100 times):
#  - epochs: 600 (eq.iters: 1800) - eval freq: 40 - batch_size: 256
# ----------------------------------------------------------------------------------------
# [0.0mins] epoch: 40 | train loss:0.66 | train acc:0.59 |
#                    | test loss: 0.64 | test acc: 0.62 |
#                    | N-Way train acc:0.29 | N-Way test acc:0.21
#           | best N-Way train acc: current=0.21 | previous=0)
#           | best test acc: current=0.62 | previous=0)
# ----------------------------------------------------------------------------------------
# [0.1mins] epoch: 80 | train loss:0.66 | train acc:0.58 |
#                    | test loss: 0.67 | test acc: 0.53 |
#                    | N-Way train acc:0.26 | N-Way test acc:0.23
#           | best N-Way train acc: current=0.23 | previous=0.21)
# ----------------------------------------------------------------------------------------
# [0.3mins] epoch: 120 | train loss:0.68 | train acc:0.59 |
#                    | test loss: 0.63 | test acc: 0.59 |
#                    | N-Way train acc:0.32 | N-Way test acc:0.27
#           | best N-Way train acc: current=0.27 | previous=0.23)
# ----------------------------------------------------------------------------------------
# [0.4mins] epoch: 160 | train loss:0.67 | train acc:0.6 |
#                    | test loss: 0.64 | test acc: 0.59 |
#                    | N-Way train acc:0.32 | N-Way test acc:0.31
#           | best N-Way train acc: current=0.31 | previous=0.27)
# ----------------------------------------------------------------------------------------
# [0.5mins] epoch: 200 | train loss:0.68 | train acc:0.59 |
#                    | test loss: 0.6 | test acc: 0.63 |
#                    | N-Way train acc:0.18 | N-Way test acc:0.38
#           | best N-Way train acc: current=0.38 | previous=0.31)
#           | best test acc: current=0.63 | previous=0.62)
# ----------------------------------------------------------------------------------------
# [0.6mins] epoch: 240 | train loss:0.66 | train acc:0.62 |
#                    | test loss: 0.65 | test acc: 0.57 |
#                    | N-Way train acc:0.32 | N-Way test acc:0.2
# ----------------------------------------------------------------------------------------
# [0.8mins] epoch: 280 | train loss:0.63 | train acc:0.61 |
#                    | test loss: 0.62 | test acc: 0.6 |
#                    | N-Way train acc:0.31 | N-Way test acc:0.32
# ----------------------------------------------------------------------------------------
# [0.9mins] epoch: 320 | train loss:0.63 | train acc:0.62 |
#                    | test loss: 0.61 | test acc: 0.58 |
#                    | N-Way train acc:0.3 | N-Way test acc:0.32
# ----------------------------------------------------------------------------------------
# [1.0mins] epoch: 360 | train loss:0.64 | train acc:0.63 |
#                    | test loss: 0.62 | test acc: 0.6 |
#                    | N-Way train acc:0.34 | N-Way test acc:0.39
#           | best N-Way train acc: current=0.39 | previous=0.38)
# ----------------------------------------------------------------------------------------
# [1.1mins] epoch: 400 | train loss:0.6 | train acc:0.63 |
#                    | test loss: 0.61 | test acc: 0.61 |
#                    | N-Way train acc:0.33 | N-Way test acc:0.3
# ----------------------------------------------------------------------------------------
# [1.2mins] epoch: 440 | train loss:0.64 | train acc:0.65 |
#                    | test loss: 0.62 | test acc: 0.58 |
#                    | N-Way train acc:0.29 | N-Way test acc:0.36
# ----------------------------------------------------------------------------------------
# [1.4mins] epoch: 480 | train loss:0.61 | train acc:0.68 |
#                    | test loss: 0.65 | test acc: 0.58 |
#                    | N-Way train acc:0.29 | N-Way test acc:0.4
#           | best N-Way train acc: current=0.4 | previous=0.39)
# ----------------------------------------------------------------------------------------
# [1.5mins] epoch: 520 | train loss:0.62 | train acc:0.68 |
#                    | test loss: 0.58 | test acc: 0.62 |
#                    | N-Way train acc:0.37 | N-Way test acc:0.38
# ----------------------------------------------------------------------------------------
# [1.6mins] epoch: 560 | train loss:0.6 | train acc:0.67 |
#                    | test loss: 0.58 | test acc: 0.62 |
#                    | N-Way train acc:0.36 | N-Way test acc:0.36
# ----------------------------------------------------------------------------------------
# [1.7mins] epoch: 600 | train loss:0.62 | train acc:0.67 |
#                    | test loss: 0.56 | test acc: 0.64 |
#                    | N-Way train acc:0.47 | N-Way test acc:0.45
#           | best N-Way train acc: current=0.45 | previous=0.4)
#           | best test acc: current=0.64 | previous=0.63)

# %%
siamese_train(epochs=600, batch_size=256, train_type='epoch', eval_freq=40, n_way=10, n_test=100, 
              embed=True, normalize=False, do_shuffle=True, 
              embed_option='facenet1', learn='only_l2')
# Out:
# starting oneshot training (evaluated by 10 N-Way for 100 times):
#  - epochs: 600 - eval freq: 40 - batch_size: 256
# ----------------------------------------------------------------------------------------
# [0.0mins] epoch: 40 | train loss:0.67 | train acc:0.6 |
#                    | test loss: 0.73 | test acc: 0.57 |
#                    | N-Way train acc:0.19 | N-Way test acc:0.23
#           | best N-Way train acc: current=0.23 | previous=0)
#           | best test acc: current=0.57 | previous=0)
# ----------------------------------------------------------------------------------------
# [0.2mins] epoch: 80 | train loss:0.67 | train acc:0.6 |
#                    | test loss: 0.66 | test acc: 0.6 |
#                    | N-Way train acc:0.25 | N-Way test acc:0.26
#           | best N-Way train acc: current=0.26 | previous=0.23)
#           | best test acc: current=0.6 | previous=0.57)
# ----------------------------------------------------------------------------------------
# [0.3mins] epoch: 120 | train loss:0.66 | train acc:0.59 |
#                    | test loss: 0.69 | test acc: 0.55 |
#                    | N-Way train acc:0.29 | N-Way test acc:0.24
# ----------------------------------------------------------------------------------------
# [0.5mins] epoch: 160 | train loss:0.63 | train acc:0.63 |
#                    | test loss: 0.63 | test acc: 0.59 |
#                    | N-Way train acc:0.3 | N-Way test acc:0.32
#           | best N-Way train acc: current=0.32 | previous=0.26)
# ----------------------------------------------------------------------------------------
# [0.6mins] epoch: 200 | train loss:0.66 | train acc:0.62 |
#                    | test loss: 0.66 | test acc: 0.54 |
#                    | N-Way train acc:0.35 | N-Way test acc:0.3
# ----------------------------------------------------------------------------------------
# [0.7mins] epoch: 240 | train loss:0.64 | train acc:0.61 |
#                    | test loss: 0.58 | test acc: 0.65 |
#                    | N-Way train acc:0.29 | N-Way test acc:0.32
#           | best test acc: current=0.65 | previous=0.6)
# ----------------------------------------------------------------------------------------
# [0.9mins] epoch: 280 | train loss:0.64 | train acc:0.62 |
#                    | test loss: 0.61 | test acc: 0.59 |
#                    | N-Way train acc:0.27 | N-Way test acc:0.38
#           | best N-Way train acc: current=0.38 | previous=0.32)
# ----------------------------------------------------------------------------------------
# [1.0mins] epoch: 320 | train loss:0.61 | train acc:0.64 |
#                    | test loss: 0.61 | test acc: 0.6 |
#                    | N-Way train acc:0.28 | N-Way test acc:0.28
# ----------------------------------------------------------------------------------------
# [1.1mins] epoch: 360 | train loss:0.62 | train acc:0.64 |
#                    | test loss: 0.64 | test acc: 0.61 |
#                    | N-Way train acc:0.27 | N-Way test acc:0.3
# ----------------------------------------------------------------------------------------
# [1.3mins] epoch: 400 | train loss:0.6 | train acc:0.65 |
#                    | test loss: 0.6 | test acc: 0.6 |
#                    | N-Way train acc:0.33 | N-Way test acc:0.27
# ----------------------------------------------------------------------------------------
# [1.4mins] epoch: 440 | train loss:0.61 | train acc:0.65 |
#                    | test loss: 0.58 | test acc: 0.63 |
#                    | N-Way train acc:0.33 | N-Way test acc:0.31
# ----------------------------------------------------------------------------------------
# [1.6mins] epoch: 480 | train loss:0.59 | train acc:0.68 |
#                    | test loss: 0.59 | test acc: 0.65 |
#                    | N-Way train acc:0.32 | N-Way test acc:0.41
#           | best N-Way train acc: current=0.41 | previous=0.38)
# ----------------------------------------------------------------------------------------
# [1.7mins] epoch: 520 | train loss:0.58 | train acc:0.66 |
#                    | test loss: 0.62 | test acc: 0.6 |
#                    | N-Way train acc:0.32 | N-Way test acc:0.38
# ----------------------------------------------------------------------------------------
# [1.8mins] epoch: 560 | train loss:0.59 | train acc:0.66 |
#                    | test loss: 0.62 | test acc: 0.58 |
#                    | N-Way train acc:0.29 | N-Way test acc:0.32
# ----------------------------------------------------------------------------------------
# [2.0mins] epoch: 600 | train loss:0.6 | train acc:0.66 |
#                    | test loss: 0.6 | test acc: 0.63 |
#                    | N-Way train acc:0.37 | N-Way test acc:0.43
#           | best N-Way train acc: current=0.43 | previous=0.41)

# %% [markdown]
# ### embed_option: 'facenet2'

# %%
siamese_train(epochs=600, batch_size=256, train_type='batch', eval_freq=40, n_way=10, n_test=100, 
              embed=True, normalize=False, do_shuffle=True, 
              embed_option='facenet1', learn='only_l2')
# Out:
# starting oneshot training (evaluated by 10 N-Way for 100 times):
#  - epochs: 600 (eq.iters: 1800) - eval freq: 40 - batch_size: 256
# ----------------------------------------------------------------------------------------
# [0.0mins] epoch: 40 | train loss:0.65 | train acc:0.59 |
#                    | test loss: 0.66 | test acc: 0.6 |
#                    | N-Way train acc:0.25 | N-Way test acc:0.28
#           | best N-Way train acc: current=0.28 | previous=0)
#           | best test acc: current=0.6 | previous=0)
# ----------------------------------------------------------------------------------------
# [0.2mins] epoch: 80 | train loss:0.67 | train acc:0.62 |
#                    | test loss: 0.63 | test acc: 0.59 |
#                    | N-Way train acc:0.2 | N-Way test acc:0.26
# ----------------------------------------------------------------------------------------
# [0.3mins] epoch: 120 | train loss:0.63 | train acc:0.62 |
#                    | test loss: 0.65 | test acc: 0.63 |
#                    | N-Way train acc:0.24 | N-Way test acc:0.24
#           | best test acc: current=0.63 | previous=0.6)
# ----------------------------------------------------------------------------------------
# [0.4mins] epoch: 160 | train loss:0.69 | train acc:0.59 |
#                    | test loss: 0.64 | test acc: 0.56 |
#                    | N-Way train acc:0.18 | N-Way test acc:0.27
# ----------------------------------------------------------------------------------------
# [0.5mins] epoch: 200 | train loss:0.62 | train acc:0.62 |
#                    | test loss: 0.64 | test acc: 0.62 |
#                    | N-Way train acc:0.32 | N-Way test acc:0.26
# ----------------------------------------------------------------------------------------
# [0.6mins] epoch: 240 | train loss:0.7 | train acc:0.57 |
#                    | test loss: 0.65 | test acc: 0.58 |
#                    | N-Way train acc:0.27 | N-Way test acc:0.32
#           | best N-Way train acc: current=0.32 | previous=0.28)
# ----------------------------------------------------------------------------------------
# [0.8mins] epoch: 280 | train loss:0.59 | train acc:0.68 |
#                    | test loss: 0.63 | test acc: 0.61 |
#                    | N-Way train acc:0.34 | N-Way test acc:0.32
# ----------------------------------------------------------------------------------------
# [0.9mins] epoch: 320 | train loss:0.66 | train acc:0.64 |
#                    | test loss: 0.63 | test acc: 0.6 |
#                    | N-Way train acc:0.23 | N-Way test acc:0.38
#           | best N-Way train acc: current=0.38 | previous=0.32)
# ----------------------------------------------------------------------------------------
# [1.0mins] epoch: 360 | train loss:0.63 | train acc:0.66 |
#                    | test loss: 0.61 | test acc: 0.62 |
#                    | N-Way train acc:0.38 | N-Way test acc:0.47
#           | best N-Way train acc: current=0.47 | previous=0.38)
# ----------------------------------------------------------------------------------------
# [1.1mins] epoch: 400 | train loss:0.62 | train acc:0.62 |
#                    | test loss: 0.66 | test acc: 0.57 |
#                    | N-Way train acc:0.32 | N-Way test acc:0.32
# ----------------------------------------------------------------------------------------
# [1.2mins] epoch: 440 | train loss:0.6 | train acc:0.66 |
#                    | test loss: 0.64 | test acc: 0.6 |
#                    | N-Way train acc:0.36 | N-Way test acc:0.26
# ----------------------------------------------------------------------------------------
# [1.4mins] epoch: 480 | train loss:0.58 | train acc:0.66 |
#                    | test loss: 0.62 | test acc: 0.62 |
#                    | N-Way train acc:0.28 | N-Way test acc:0.33
# ----------------------------------------------------------------------------------------
# [1.5mins] epoch: 520 | train loss:0.6 | train acc:0.63 |
#                    | test loss: 0.64 | test acc: 0.6 |
#                    | N-Way train acc:0.36 | N-Way test acc:0.31
# ----------------------------------------------------------------------------------------
# [1.6mins] epoch: 560 | train loss:0.62 | train acc:0.65 |
#                    | test loss: 0.64 | test acc: 0.61 |
#                    | N-Way train acc:0.38 | N-Way test acc:0.34
# ----------------------------------------------------------------------------------------
# [1.7mins] epoch: 600 | train loss:0.62 | train acc:0.66 |
#                    | test loss: 0.59 | test acc: 0.61 |
#                    | N-Way train acc:0.34 | N-Way test acc:0.35

# %%
siamese_train(epochs=600, batch_size=256, train_type='epoch', eval_freq=40, n_way=10, n_test=100, 
              embed=True, normalize=False, do_shuffle=True, 
              embed_option='facenet2', learn='only_l2')
# Out:
# starting oneshot training (evaluated by 10 N-Way for 100 times):
#  - epochs: 600 - eval freq: 40 - batch_size: 256
# ----------------------------------------------------------------------------------------
# [0.0mins] epoch: 40 | train loss:0.68 | train acc:0.59 |
#                    | test loss: 0.59 | test acc: 0.6 |
#                    | N-Way train acc:0.19 | N-Way test acc:0.24
#           | best N-Way train acc: current=0.24 | previous=0)
#           | best test acc: current=0.6 | previous=0)
# ----------------------------------------------------------------------------------------
# [0.2mins] epoch: 80 | train loss:0.66 | train acc:0.6 |
#                    | test loss: 0.64 | test acc: 0.61 |
#                    | N-Way train acc:0.24 | N-Way test acc:0.25
#           | best N-Way train acc: current=0.25 | previous=0.24)
#           | best test acc: current=0.61 | previous=0.6)
# ----------------------------------------------------------------------------------------
# [0.3mins] epoch: 120 | train loss:0.67 | train acc:0.59 |
#                    | test loss: 0.65 | test acc: 0.61 |
#                    | N-Way train acc:0.32 | N-Way test acc:0.27
#           | best N-Way train acc: current=0.27 | previous=0.25)
# ----------------------------------------------------------------------------------------
# [0.5mins] epoch: 160 | train loss:0.66 | train acc:0.6 |
#                    | test loss: 0.66 | test acc: 0.56 |
#                    | N-Way train acc:0.26 | N-Way test acc:0.39
#           | best N-Way train acc: current=0.39 | previous=0.27)
# ----------------------------------------------------------------------------------------
# [0.6mins] epoch: 200 | train loss:0.61 | train acc:0.63 |
#                    | test loss: 0.63 | test acc: 0.56 |
#                    | N-Way train acc:0.28 | N-Way test acc:0.31
# ----------------------------------------------------------------------------------------
# [0.7mins] epoch: 240 | train loss:0.62 | train acc:0.63 |
#                    | test loss: 0.64 | test acc: 0.63 |
#                    | N-Way train acc:0.38 | N-Way test acc:0.33
#           | best test acc: current=0.63 | previous=0.61)
# ----------------------------------------------------------------------------------------
# [0.9mins] epoch: 280 | train loss:0.63 | train acc:0.62 |
#                    | test loss: 0.64 | test acc: 0.59 |
#                    | N-Way train acc:0.31 | N-Way test acc:0.3
# ----------------------------------------------------------------------------------------
# [1.0mins] epoch: 320 | train loss:0.62 | train acc:0.63 |
#                    | test loss: 0.58 | test acc: 0.65 |
#                    | N-Way train acc:0.35 | N-Way test acc:0.34
#           | best test acc: current=0.65 | previous=0.63)
# ----------------------------------------------------------------------------------------
# [1.1mins] epoch: 360 | train loss:0.6 | train acc:0.64 |
#                    | test loss: 0.64 | test acc: 0.6 |
#                    | N-Way train acc:0.28 | N-Way test acc:0.32
# ----------------------------------------------------------------------------------------
# [1.3mins] epoch: 400 | train loss:0.61 | train acc:0.64 |
#                    | test loss: 0.62 | test acc: 0.62 |
#                    | N-Way train acc:0.35 | N-Way test acc:0.22
# ----------------------------------------------------------------------------------------
# [1.4mins] epoch: 440 | train loss:0.6 | train acc:0.66 |
#                    | test loss: 0.62 | test acc: 0.58 |
#                    | N-Way train acc:0.44 | N-Way test acc:0.34
# ----------------------------------------------------------------------------------------
# [1.5mins] epoch: 480 | train loss:0.62 | train acc:0.65 |
#                    | test loss: 0.58 | test acc: 0.65 |
#                    | N-Way train acc:0.38 | N-Way test acc:0.32
# ----------------------------------------------------------------------------------------
# [1.7mins] epoch: 520 | train loss:0.6 | train acc:0.66 |
#                    | test loss: 0.63 | test acc: 0.59 |
#                    | N-Way train acc:0.47 | N-Way test acc:0.28
# ----------------------------------------------------------------------------------------
# [1.8mins] epoch: 560 | train loss:0.58 | train acc:0.67 |
#                    | test loss: 0.61 | test acc: 0.54 |
#                    | N-Way train acc:0.37 | N-Way test acc:0.41
#           | best N-Way train acc: current=0.41 | previous=0.39)
# ----------------------------------------------------------------------------------------
# [2.0mins] epoch: 600 | train loss:0.57 | train acc:0.69 |
#                    | test loss: 0.61 | test acc: 0.62 |
#                    | N-Way train acc:0.38 | N-Way test acc:0.42
#           | best N-Way train acc: current=0.42 | previous=0.41)

# %% [markdown]
# ## Learn before L2
#     - without normalization

# %% [markdown]
# ### embed_option: 'face_recognition'

# %%
siamese_train(epochs=600, batch_size=256, train_type='batch', eval_freq=40, n_way=10, n_test=100, 
              embed=True, normalize=False, do_shuffle=True, 
              embed_option='face_recognition', learn='before_l2')
# Out:
# starting oneshot training (evaluated by 10 N-Way for 100 times):
#  - epochs: 600 (eq.iters: 1800) - eval freq: 40 - batch_size: 256
# ----------------------------------------------------------------------------------------
# [0.0mins] epoch: 40 | train loss:0.57 | train acc:0.93 |
#                    | test loss: 0.56 | test acc: 0.93 |
#                    | N-Way train acc:0.94 | N-Way test acc:0.93
#           | best N-Way train acc: current=0.93 | previous=0)
#           | best test acc: current=0.93 | previous=0)
# ----------------------------------------------------------------------------------------
# [0.2mins] epoch: 80 | train loss:0.53 | train acc:0.85 |
#                    | test loss: 0.51 | test acc: 0.89 |
#                    | N-Way train acc:0.95 | N-Way test acc:0.91
# ----------------------------------------------------------------------------------------
# [0.3mins] epoch: 120 | train loss:0.51 | train acc:0.82 |
#                    | test loss: 0.51 | test acc: 0.82 |
#                    | N-Way train acc:0.91 | N-Way test acc:0.88
# ----------------------------------------------------------------------------------------
# [0.4mins] epoch: 160 | train loss:0.51 | train acc:0.81 |
#                    | test loss: 0.5 | test acc: 0.78 |
#                    | N-Way train acc:0.94 | N-Way test acc:0.91
# ----------------------------------------------------------------------------------------
# [0.6mins] epoch: 200 | train loss:0.5 | train acc:0.81 |
#                    | test loss: 0.47 | test acc: 0.86 |
#                    | N-Way train acc:0.92 | N-Way test acc:0.93
# ----------------------------------------------------------------------------------------
# [0.7mins] epoch: 240 | train loss:0.48 | train acc:0.81 |
#                    | test loss: 0.45 | test acc: 0.82 |
#                    | N-Way train acc:0.94 | N-Way test acc:0.85
# ----------------------------------------------------------------------------------------
# [0.8mins] epoch: 280 | train loss:0.46 | train acc:0.8 |
#                    | test loss: 0.46 | test acc: 0.84 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.88
# ----------------------------------------------------------------------------------------
# [0.9mins] epoch: 320 | train loss:0.46 | train acc:0.87 |
#                    | test loss: 0.44 | test acc: 0.8 |
#                    | N-Way train acc:0.91 | N-Way test acc:0.9
# ----------------------------------------------------------------------------------------
# [1.1mins] epoch: 360 | train loss:0.46 | train acc:0.88 |
#                    | test loss: 0.45 | test acc: 0.84 |
#                    | N-Way train acc:0.86 | N-Way test acc:0.91
# ----------------------------------------------------------------------------------------
# [1.2mins] epoch: 400 | train loss:0.46 | train acc:0.86 |
#                    | test loss: 0.47 | test acc: 0.82 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.88
# ----------------------------------------------------------------------------------------
# [1.3mins] epoch: 440 | train loss:0.44 | train acc:0.89 |
#                    | test loss: 0.44 | test acc: 0.88 |
#                    | N-Way train acc:0.92 | N-Way test acc:0.9
# ----------------------------------------------------------------------------------------
# [1.4mins] epoch: 480 | train loss:0.43 | train acc:0.89 |
#                    | test loss: 0.45 | test acc: 0.84 |
#                    | N-Way train acc:0.86 | N-Way test acc:0.8
# ----------------------------------------------------------------------------------------
# [1.6mins] epoch: 520 | train loss:0.42 | train acc:0.91 |
#                    | test loss: 0.44 | test acc: 0.84 |
#                    | N-Way train acc:0.88 | N-Way test acc:0.8
# ----------------------------------------------------------------------------------------
# [1.7mins] epoch: 560 | train loss:0.42 | train acc:0.9 |
#                    | test loss: 0.42 | test acc: 0.84 |
#                    | N-Way train acc:0.88 | N-Way test acc:0.76
# ----------------------------------------------------------------------------------------
# [1.8mins] epoch: 600 | train loss:0.41 | train acc:0.92 |
#                    | test loss: 0.43 | test acc: 0.89 |
#                    | N-Way train acc:0.89 | N-Way test acc:0.79

# %%
siamese_train(epochs=600, batch_size=256, train_type='epoch', eval_freq=40, n_way=10, n_test=100, 
              embed=True, normalize=False, do_shuffle=True, 
              embed_option='face_recognition', learn='before_l2')
# Out:
# starting oneshot training (evaluated by 10 N-Way for 100 times):
#  - epochs: 600 - eval freq: 40 - batch_size: 256
# ----------------------------------------------------------------------------------------
# [0.1mins] epoch: 40 | train loss:0.61 | train acc:0.9 |
#                    | test loss: 0.61 | test acc: 0.86 |
#                    | N-Way train acc:0.95 | N-Way test acc:0.9
#           | best N-Way train acc: current=0.9 | previous=0)
#           | best test acc: current=0.86 | previous=0)
# ----------------------------------------------------------------------------------------
# [0.2mins] epoch: 80 | train loss:0.57 | train acc:0.92 |
#                    | test loss: 0.56 | test acc: 0.9 |
#                    | N-Way train acc:0.93 | N-Way test acc:0.96
#           | best N-Way train acc: current=0.96 | previous=0.9)
#           | best test acc: current=0.9 | previous=0.86)
# ----------------------------------------------------------------------------------------
# [0.3mins] epoch: 120 | train loss:0.54 | train acc:0.87 |
#                    | test loss: 0.53 | test acc: 0.89 |
#                    | N-Way train acc:0.92 | N-Way test acc:0.87
# ----------------------------------------------------------------------------------------
# [0.5mins] epoch: 160 | train loss:0.52 | train acc:0.83 |
#                    | test loss: 0.53 | test acc: 0.82 |
#                    | N-Way train acc:0.99 | N-Way test acc:0.89
# ----------------------------------------------------------------------------------------
# [0.6mins] epoch: 200 | train loss:0.5 | train acc:0.8 |
#                    | test loss: 0.49 | test acc: 0.82 |
#                    | N-Way train acc:0.93 | N-Way test acc:0.93
# ----------------------------------------------------------------------------------------
# [0.8mins] epoch: 240 | train loss:0.5 | train acc:0.79 |
#                    | test loss: 0.51 | test acc: 0.79 |
#                    | N-Way train acc:0.94 | N-Way test acc:0.93
# ----------------------------------------------------------------------------------------
# [0.9mins] epoch: 280 | train loss:0.49 | train acc:0.8 |
#                    | test loss: 0.48 | test acc: 0.79 |
#                    | N-Way train acc:0.95 | N-Way test acc:0.89
# ----------------------------------------------------------------------------------------
# [1.1mins] epoch: 320 | train loss:0.48 | train acc:0.82 |
#                    | test loss: 0.48 | test acc: 0.82 |
#                    | N-Way train acc:0.87 | N-Way test acc:0.89
# ----------------------------------------------------------------------------------------
# [1.2mins] epoch: 360 | train loss:0.47 | train acc:0.84 |
#                    | test loss: 0.48 | test acc: 0.75 |
#                    | N-Way train acc:0.88 | N-Way test acc:0.89
# ----------------------------------------------------------------------------------------
# [1.4mins] epoch: 400 | train loss:0.45 | train acc:0.85 |
#                    | test loss: 0.45 | test acc: 0.84 |
#                    | N-Way train acc:0.89 | N-Way test acc:0.87
# ----------------------------------------------------------------------------------------
# [1.5mins] epoch: 440 | train loss:0.46 | train acc:0.85 |
#                    | test loss: 0.45 | test acc: 0.87 |
#                    | N-Way train acc:0.87 | N-Way test acc:0.88
# ----------------------------------------------------------------------------------------
# [1.6mins] epoch: 480 | train loss:0.45 | train acc:0.86 |
#                    | test loss: 0.46 | test acc: 0.81 |
#                    | N-Way train acc:0.91 | N-Way test acc:0.87
# ----------------------------------------------------------------------------------------
# [1.8mins] epoch: 520 | train loss:0.45 | train acc:0.86 |
#                    | test loss: 0.44 | test acc: 0.83 |
#                    | N-Way train acc:0.83 | N-Way test acc:0.85
# ----------------------------------------------------------------------------------------
# [1.9mins] epoch: 560 | train loss:0.44 | train acc:0.88 |
#                    | test loss: 0.45 | test acc: 0.83 |
#                    | N-Way train acc:0.94 | N-Way test acc:0.88
# ----------------------------------------------------------------------------------------
# [2.1mins] epoch: 600 | train loss:0.44 | train acc:0.89 |
#                    | test loss: 0.46 | test acc: 0.82 |
#                    | N-Way train acc:0.87 | N-Way test acc:0.83

# %% [markdown]
# ### embed_option: 'facenet1'

# %%
siamese_train(epochs=600, batch_size=256, train_type='batch', eval_freq=40, n_way=10, n_test=100, 
              embed=True, normalize=False, do_shuffle=True, 
              embed_option='facenet1', learn='before_l2')
# Out:
# starting oneshot training (evaluated by 10 N-Way for 100 times):
#  - epochs: 600 (eq.iters: 1800) - eval freq: 40 - batch_size: 256
# ----------------------------------------------------------------------------------------
# [0.0mins] epoch: 40 | train loss:0.48 | train acc:0.8 |
#                    | test loss: 0.54 | test acc: 0.71 |
#                    | N-Way train acc:0.81 | N-Way test acc:0.62
#           | best N-Way train acc: current=0.62 | previous=0)
#           | best test acc: current=0.71 | previous=0)
# ----------------------------------------------------------------------------------------
# [0.2mins] epoch: 80 | train loss:0.41 | train acc:0.92 |
#                    | test loss: 0.55 | test acc: 0.76 |
#                    | N-Way train acc:0.91 | N-Way test acc:0.68
#           | best N-Way train acc: current=0.68 | previous=0.62)
#           | best test acc: current=0.76 | previous=0.71)
# ----------------------------------------------------------------------------------------
# [0.3mins] epoch: 120 | train loss:0.35 | train acc:0.95 |
#                    | test loss: 0.53 | test acc: 0.73 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.6
# ----------------------------------------------------------------------------------------
# [0.4mins] epoch: 160 | train loss:0.34 | train acc:0.95 |
#                    | test loss: 0.52 | test acc: 0.74 |
#                    | N-Way train acc:0.98 | N-Way test acc:0.6
# ----------------------------------------------------------------------------------------
# [0.5mins] epoch: 200 | train loss:0.31 | train acc:0.96 |
#                    | test loss: 0.51 | test acc: 0.74 |
#                    | N-Way train acc:0.94 | N-Way test acc:0.55
# ----------------------------------------------------------------------------------------
# [0.6mins] epoch: 240 | train loss:0.28 | train acc:0.98 |
#                    | test loss: 0.52 | test acc: 0.8 |
#                    | N-Way train acc:0.94 | N-Way test acc:0.56
#           | best test acc: current=0.8 | previous=0.76)
# ----------------------------------------------------------------------------------------
# [0.8mins] epoch: 280 | train loss:0.26 | train acc:0.98 |
#                    | test loss: 0.56 | test acc: 0.73 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.61
# ----------------------------------------------------------------------------------------
# [0.9mins] epoch: 320 | train loss:0.22 | train acc:1.0 |
#                    | test loss: 0.54 | test acc: 0.76 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.58
# ----------------------------------------------------------------------------------------
# [1.0mins] epoch: 360 | train loss:0.22 | train acc:0.97 |
#                    | test loss: 0.51 | test acc: 0.77 |
#                    | N-Way train acc:0.98 | N-Way test acc:0.64
# ----------------------------------------------------------------------------------------
# [1.1mins] epoch: 400 | train loss:0.21 | train acc:0.99 |
#                    | test loss: 0.54 | test acc: 0.74 |
#                    | N-Way train acc:0.98 | N-Way test acc:0.63
# ----------------------------------------------------------------------------------------
# [1.3mins] epoch: 440 | train loss:0.19 | train acc:0.99 |
#                    | test loss: 0.59 | test acc: 0.64 |
#                    | N-Way train acc:1.0 | N-Way test acc:0.64
# ----------------------------------------------------------------------------------------
# [1.4mins] epoch: 480 | train loss:0.18 | train acc:0.99 |
#                    | test loss: 0.51 | test acc: 0.75 |
#                    | N-Way train acc:1.0 | N-Way test acc:0.53
# ----------------------------------------------------------------------------------------
# [1.5mins] epoch: 520 | train loss:0.16 | train acc:0.99 |
#                    | test loss: 0.53 | test acc: 0.74 |
#                    | N-Way train acc:0.94 | N-Way test acc:0.64
# ----------------------------------------------------------------------------------------
# [1.6mins] epoch: 560 | train loss:0.16 | train acc:0.99 |
#                    | test loss: 0.57 | test acc: 0.71 |
#                    | N-Way train acc:0.99 | N-Way test acc:0.55
# ----------------------------------------------------------------------------------------
# [1.7mins] epoch: 600 | train loss:0.15 | train acc:0.99 |
#                    | test loss: 0.59 | test acc: 0.73 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.64

# %%
siamese_train(epochs=600, batch_size=256, train_type='epoch', eval_freq=40, n_way=10, n_test=100, 
              embed=True, normalize=False, do_shuffle=True, 
              embed_option='facenet1', learn='before_l2')
# Out:
# starting oneshot training (evaluated by 10 N-Way for 100 times):
#  - epochs: 600 - eval freq: 40 - batch_size: 256
# ----------------------------------------------------------------------------------------
# [0.1mins] epoch: 40 | train loss:0.52 | train acc:0.73 |
#                    | test loss: 0.57 | test acc: 0.71 |
#                    | N-Way train acc:0.78 | N-Way test acc:0.63
#           | best N-Way train acc: current=0.63 | previous=0)
#           | best test acc: current=0.71 | previous=0)
# ----------------------------------------------------------------------------------------
# [0.2mins] epoch: 80 | train loss:0.47 | train acc:0.81 |
#                    | test loss: 0.55 | test acc: 0.7 |
#                    | N-Way train acc:0.8 | N-Way test acc:0.54
# ----------------------------------------------------------------------------------------
# [0.3mins] epoch: 120 | train loss:0.43 | train acc:0.87 |
#                    | test loss: 0.52 | test acc: 0.74 |
#                    | N-Way train acc:0.92 | N-Way test acc:0.57
#           | best test acc: current=0.74 | previous=0.71)
# ----------------------------------------------------------------------------------------
# [0.5mins] epoch: 160 | train loss:0.39 | train acc:0.93 |
#                    | test loss: 0.56 | test acc: 0.75 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.56
#           | best test acc: current=0.75 | previous=0.74)
# ----------------------------------------------------------------------------------------
# [0.6mins] epoch: 200 | train loss:0.36 | train acc:0.94 |
#                    | test loss: 0.56 | test acc: 0.71 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.6
# ----------------------------------------------------------------------------------------
# [0.8mins] epoch: 240 | train loss:0.33 | train acc:0.96 |
#                    | test loss: 0.5 | test acc: 0.74 |
#                    | N-Way train acc:0.95 | N-Way test acc:0.54
# ----------------------------------------------------------------------------------------
# [0.9mins] epoch: 280 | train loss:0.31 | train acc:0.98 |
#                    | test loss: 0.47 | test acc: 0.81 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.54
#           | best test acc: current=0.81 | previous=0.75)
# ----------------------------------------------------------------------------------------
# [1.1mins] epoch: 320 | train loss:0.28 | train acc:0.98 |
#                    | test loss: 0.52 | test acc: 0.76 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.68
#           | best N-Way train acc: current=0.68 | previous=0.63)
# ----------------------------------------------------------------------------------------
# [1.2mins] epoch: 360 | train loss:0.25 | train acc:0.99 |
#                    | test loss: 0.43 | test acc: 0.8 |
#                    | N-Way train acc:0.99 | N-Way test acc:0.6
# ----------------------------------------------------------------------------------------
# [1.3mins] epoch: 400 | train loss:0.25 | train acc:0.98 |
#                    | test loss: 0.5 | test acc: 0.77 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.49
# ----------------------------------------------------------------------------------------
# [1.5mins] epoch: 440 | train loss:0.23 | train acc:0.98 |
#                    | test loss: 0.46 | test acc: 0.76 |
#                    | N-Way train acc:0.98 | N-Way test acc:0.58
# ----------------------------------------------------------------------------------------
# [1.6mins] epoch: 480 | train loss:0.2 | train acc:0.99 |
#                    | test loss: 0.46 | test acc: 0.76 |
#                    | N-Way train acc:0.98 | N-Way test acc:0.58
# ----------------------------------------------------------------------------------------
# [1.8mins] epoch: 520 | train loss:0.19 | train acc:0.98 |
#                    | test loss: 0.52 | test acc: 0.72 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.66
# ----------------------------------------------------------------------------------------
# [1.9mins] epoch: 560 | train loss:0.18 | train acc:0.99 |
#                    | test loss: 0.43 | test acc: 0.8 |
#                    | N-Way train acc:0.98 | N-Way test acc:0.52
# ----------------------------------------------------------------------------------------
# [2.0mins] epoch: 600 | train loss:0.17 | train acc:0.99 |
#                    | test loss: 0.48 | test acc: 0.8 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.67

# %% [markdown]
# ### embed_option: 'facenet2'

# %%
siamese_train(epochs=600, batch_size=256, train_type='batch', eval_freq=40, n_way=10, n_test=100, 
              embed=True, normalize=False, do_shuffle=True, 
              embed_option='facenet2', learn='before_l2')
# Out:
# starting oneshot training (evaluated by 10 N-Way for 100 times):
#  - epochs: 600 (eq.iters: 1800) - eval freq: 40 - batch_size: 256
# ----------------------------------------------------------------------------------------
# [0.0mins] epoch: 40 | train loss:0.56 | train acc:0.7 |
#                    | test loss: 0.58 | test acc: 0.69 |
#                    | N-Way train acc:0.63 | N-Way test acc:0.54
#           | best N-Way train acc: current=0.54 | previous=0)
#           | best test acc: current=0.69 | previous=0)
# ----------------------------------------------------------------------------------------
# [0.2mins] epoch: 80 | train loss:0.49 | train acc:0.79 |
#                    | test loss: 0.58 | test acc: 0.65 |
#                    | N-Way train acc:0.83 | N-Way test acc:0.54
# ----------------------------------------------------------------------------------------
# [0.3mins] epoch: 120 | train loss:0.47 | train acc:0.81 |
#                    | test loss: 0.59 | test acc: 0.73 |
#                    | N-Way train acc:0.85 | N-Way test acc:0.64
#           | best N-Way train acc: current=0.64 | previous=0.54)
#           | best test acc: current=0.73 | previous=0.69)
# ----------------------------------------------------------------------------------------
# [0.4mins] epoch: 160 | train loss:0.43 | train acc:0.87 |
#                    | test loss: 0.54 | test acc: 0.74 |
#                    | N-Way train acc:0.91 | N-Way test acc:0.57
#           | best test acc: current=0.74 | previous=0.73)
# ----------------------------------------------------------------------------------------
# [0.5mins] epoch: 200 | train loss:0.4 | train acc:0.93 |
#                    | test loss: 0.52 | test acc: 0.74 |
#                    | N-Way train acc:0.89 | N-Way test acc:0.58
# ----------------------------------------------------------------------------------------
# [0.7mins] epoch: 240 | train loss:0.37 | train acc:0.93 |
#                    | test loss: 0.53 | test acc: 0.75 |
#                    | N-Way train acc:0.89 | N-Way test acc:0.63
#           | best test acc: current=0.75 | previous=0.74)
# ----------------------------------------------------------------------------------------
# [0.8mins] epoch: 280 | train loss:0.36 | train acc:0.94 |
#                    | test loss: 0.52 | test acc: 0.76 |
#                    | N-Way train acc:0.98 | N-Way test acc:0.63
#           | best test acc: current=0.76 | previous=0.75)
# ----------------------------------------------------------------------------------------
# [0.9mins] epoch: 320 | train loss:0.34 | train acc:0.95 |
#                    | test loss: 0.5 | test acc: 0.81 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.61
#           | best test acc: current=0.81 | previous=0.76)
# ----------------------------------------------------------------------------------------
# [1.0mins] epoch: 360 | train loss:0.31 | train acc:0.96 |
#                    | test loss: 0.55 | test acc: 0.73 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.58
# ----------------------------------------------------------------------------------------
# [1.1mins] epoch: 400 | train loss:0.29 | train acc:0.98 |
#                    | test loss: 0.5 | test acc: 0.74 |
#                    | N-Way train acc:0.94 | N-Way test acc:0.62
# ----------------------------------------------------------------------------------------
# [1.3mins] epoch: 440 | train loss:0.29 | train acc:0.98 |
#                    | test loss: 0.46 | test acc: 0.8 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.5
# ----------------------------------------------------------------------------------------
# [1.4mins] epoch: 480 | train loss:0.27 | train acc:0.96 |
#                    | test loss: 0.48 | test acc: 0.74 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.52
# ----------------------------------------------------------------------------------------
# [1.5mins] epoch: 520 | train loss:0.24 | train acc:0.98 |
#                    | test loss: 0.49 | test acc: 0.76 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.54
# ----------------------------------------------------------------------------------------
# [1.6mins] epoch: 560 | train loss:0.26 | train acc:0.97 |
#                    | test loss: 0.55 | test acc: 0.76 |
#                    | N-Way train acc:0.98 | N-Way test acc:0.61
# ----------------------------------------------------------------------------------------
# [1.8mins] epoch: 600 | train loss:0.22 | train acc:0.98 |
#                    | test loss: 0.48 | test acc: 0.78 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.56

# %%
siamese_train(epochs=600, batch_size=256, train_type='epoch', eval_freq=40, n_way=10, n_test=100, 
              embed=True, normalize=False, do_shuffle=True, 
              embed_option='facenet2', learn='before_l2')
# Out:
# starting oneshot training (evaluated by 10 N-Way for 100 times):
#  - epochs: 600 - eval freq: 40 - batch_size: 256
# ----------------------------------------------------------------------------------------
# [0.1mins] epoch: 40 | train loss:0.53 | train acc:0.72 |
#                    | test loss: 0.6 | test acc: 0.62 |
#                    | N-Way train acc:0.62 | N-Way test acc:0.53
#           | best N-Way train acc: current=0.53 | previous=0)
#           | best test acc: current=0.62 | previous=0)
# ----------------------------------------------------------------------------------------
# [0.2mins] epoch: 80 | train loss:0.48 | train acc:0.79 |
#                    | test loss: 0.57 | test acc: 0.71 |
#                    | N-Way train acc:0.81 | N-Way test acc:0.52
#           | best test acc: current=0.71 | previous=0.62)
# ----------------------------------------------------------------------------------------
# [0.3mins] epoch: 120 | train loss:0.44 | train acc:0.85 |
#                    | test loss: 0.59 | test acc: 0.67 |
#                    | N-Way train acc:0.9 | N-Way test acc:0.69
#           | best N-Way train acc: current=0.69 | previous=0.53)
# ----------------------------------------------------------------------------------------
# [0.5mins] epoch: 160 | train loss:0.41 | train acc:0.91 |
#                    | test loss: 0.54 | test acc: 0.75 |
#                    | N-Way train acc:0.95 | N-Way test acc:0.61
#           | best test acc: current=0.75 | previous=0.71)
# ----------------------------------------------------------------------------------------
# [0.6mins] epoch: 200 | train loss:0.38 | train acc:0.94 |
#                    | test loss: 0.58 | test acc: 0.67 |
#                    | N-Way train acc:0.93 | N-Way test acc:0.63
# ----------------------------------------------------------------------------------------
# [0.8mins] epoch: 240 | train loss:0.34 | train acc:0.94 |
#                    | test loss: 0.54 | test acc: 0.74 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.62
# ----------------------------------------------------------------------------------------
# [0.9mins] epoch: 280 | train loss:0.31 | train acc:0.97 |
#                    | test loss: 0.54 | test acc: 0.76 |
#                    | N-Way train acc:0.93 | N-Way test acc:0.71
#           | best N-Way train acc: current=0.71 | previous=0.69)
#           | best test acc: current=0.76 | previous=0.75)
# ----------------------------------------------------------------------------------------
# [1.1mins] epoch: 320 | train loss:0.28 | train acc:0.98 |
#                    | test loss: 0.5 | test acc: 0.74 |
#                    | N-Way train acc:0.94 | N-Way test acc:0.59
# ----------------------------------------------------------------------------------------
# [1.2mins] epoch: 360 | train loss:0.26 | train acc:0.99 |
#                    | test loss: 0.56 | test acc: 0.73 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.6
# ----------------------------------------------------------------------------------------
# [1.3mins] epoch: 400 | train loss:0.24 | train acc:0.99 |
#                    | test loss: 0.49 | test acc: 0.76 |
#                    | N-Way train acc:0.98 | N-Way test acc:0.61
# ----------------------------------------------------------------------------------------
# [1.5mins] epoch: 440 | train loss:0.23 | train acc:0.98 |
#                    | test loss: 0.54 | test acc: 0.74 |
#                    | N-Way train acc:0.99 | N-Way test acc:0.56
# ----------------------------------------------------------------------------------------
# [1.6mins] epoch: 480 | train loss:0.21 | train acc:0.98 |
#                    | test loss: 0.47 | test acc: 0.8 |
#                    | N-Way train acc:0.99 | N-Way test acc:0.49
#           | best test acc: current=0.8 | previous=0.76)
# ----------------------------------------------------------------------------------------
# [1.8mins] epoch: 520 | train loss:0.2 | train acc:0.99 |
#                    | test loss: 0.47 | test acc: 0.76 |
#                    | N-Way train acc:0.99 | N-Way test acc:0.6
# ----------------------------------------------------------------------------------------
# [1.9mins] epoch: 560 | train loss:0.18 | train acc:0.99 |
#                    | test loss: 0.49 | test acc: 0.74 |
#                    | N-Way train acc:0.99 | N-Way test acc:0.55
# ----------------------------------------------------------------------------------------
# [2.0mins] epoch: 600 | train loss:0.17 | train acc:0.99 |
#                    | test loss: 0.44 | test acc: 0.78 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.52

# %% [markdown]
# ## Learn Before and After L2
#     - without normalization

# %% [markdown]
# ### embed_option: 'face_recognition'

# %%
siamese_train(epochs=600, batch_size=256, train_type='batch', eval_freq=40, n_way=10, n_test=100, 
              embed=True, normalize=False, do_shuffle=True, 
              embed_option='face_recognition', learn='before_after_l2')
# Out:
# starting oneshot training (evaluated by 10 N-Way for 100 times):
#  - epochs: 600 (eq.iters: 1800) - eval freq: 40 - batch_size: 256
# ----------------------------------------------------------------------------------------
# [0.0mins] epoch: 40 | train loss:0.67 | train acc:0.73 |
#                    | test loss: 0.68 | test acc: 0.71 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.96
#           | best N-Way train acc: current=0.96 | previous=0)
#           | best test acc: current=0.71 | previous=0)
# ----------------------------------------------------------------------------------------
# [0.2mins] epoch: 80 | train loss:0.6 | train acc:0.79 |
#                    | test loss: 0.61 | test acc: 0.77 |
#                    | N-Way train acc:0.86 | N-Way test acc:0.91
#           | best test acc: current=0.77 | previous=0.71)
# ----------------------------------------------------------------------------------------
# [0.3mins] epoch: 120 | train loss:0.5 | train acc:0.88 |
#                    | test loss: 0.51 | test acc: 0.85 |
#                    | N-Way train acc:0.94 | N-Way test acc:0.9
#           | best test acc: current=0.85 | previous=0.77)
# ----------------------------------------------------------------------------------------
# [0.4mins] epoch: 160 | train loss:0.48 | train acc:0.85 |
#                    | test loss: 0.43 | test acc: 0.91 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.91
#           | best test acc: current=0.91 | previous=0.85)
# ----------------------------------------------------------------------------------------
# [0.6mins] epoch: 200 | train loss:0.41 | train acc:0.91 |
#                    | test loss: 0.44 | test acc: 0.88 |
#                    | N-Way train acc:0.9 | N-Way test acc:0.94
# ----------------------------------------------------------------------------------------
# [0.7mins] epoch: 240 | train loss:0.38 | train acc:0.93 |
#                    | test loss: 0.4 | test acc: 0.84 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.93
# ----------------------------------------------------------------------------------------
# [0.8mins] epoch: 280 | train loss:0.34 | train acc:0.93 |
#                    | test loss: 0.36 | test acc: 0.91 |
#                    | N-Way train acc:0.93 | N-Way test acc:0.92
# ----------------------------------------------------------------------------------------
# [0.9mins] epoch: 320 | train loss:0.36 | train acc:0.91 |
#                    | test loss: 0.37 | test acc: 0.88 |
#                    | N-Way train acc:0.93 | N-Way test acc:0.89
# ----------------------------------------------------------------------------------------
# [1.1mins] epoch: 360 | train loss:0.33 | train acc:0.92 |
#                    | test loss: 0.38 | test acc: 0.87 |
#                    | N-Way train acc:0.91 | N-Way test acc:0.96
# ----------------------------------------------------------------------------------------
# [1.2mins] epoch: 400 | train loss:0.29 | train acc:0.94 |
#                    | test loss: 0.3 | test acc: 0.93 |
#                    | N-Way train acc:0.93 | N-Way test acc:0.9
#           | best test acc: current=0.93 | previous=0.91)
# ----------------------------------------------------------------------------------------
# [1.3mins] epoch: 440 | train loss:0.31 | train acc:0.94 |
#                    | test loss: 0.34 | test acc: 0.9 |
#                    | N-Way train acc:0.88 | N-Way test acc:0.85
# ----------------------------------------------------------------------------------------
# [1.5mins] epoch: 480 | train loss:0.31 | train acc:0.92 |
#                    | test loss: 0.33 | test acc: 0.9 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.85
# ----------------------------------------------------------------------------------------
# [1.6mins] epoch: 520 | train loss:0.24 | train acc:0.95 |
#                    | test loss: 0.29 | test acc: 0.92 |
#                    | N-Way train acc:0.95 | N-Way test acc:0.94
# ----------------------------------------------------------------------------------------
# [1.7mins] epoch: 560 | train loss:0.25 | train acc:0.96 |
#                    | test loss: 0.3 | test acc: 0.91 |
#                    | N-Way train acc:0.93 | N-Way test acc:0.92
# ----------------------------------------------------------------------------------------
# [1.9mins] epoch: 600 | train loss:0.27 | train acc:0.93 |
#                    | test loss: 0.29 | test acc: 0.91 |
#                    | N-Way train acc:0.91 | N-Way test acc:0.95

# %%
siamese_train(epochs=600, batch_size=256, train_type='epoch', eval_freq=40, n_way=10, n_test=100, 
              embed=True, normalize=False, do_shuffle=True, 
              embed_option='face_recognition', learn='before_after_l2')
# Out:
# starting oneshot training (evaluated by 10 N-Way for 100 times):
#  - epochs: 600 - eval freq: 40 - batch_size: 256
# ----------------------------------------------------------------------------------------
# [0.1mins] epoch: 40 | train loss:0.69 | train acc:0.83 |
#                    | test loss: 0.69 | test acc: 0.81 |
#                    | N-Way train acc:0.92 | N-Way test acc:0.92
#           | best N-Way train acc: current=0.92 | previous=0)
#           | best test acc: current=0.81 | previous=0)
# ----------------------------------------------------------------------------------------
# [0.2mins] epoch: 80 | train loss:0.69 | train acc:0.72 |
#                    | test loss: 0.69 | test acc: 0.63 |
#                    | N-Way train acc:0.99 | N-Way test acc:0.97
#           | best N-Way train acc: current=0.97 | previous=0.92)
# ----------------------------------------------------------------------------------------
# [0.3mins] epoch: 120 | train loss:0.69 | train acc:0.59 |
#                    | test loss: 0.69 | test acc: 0.6 |
#                    | N-Way train acc:0.94 | N-Way test acc:0.94
# ----------------------------------------------------------------------------------------
# [0.5mins] epoch: 160 | train loss:0.69 | train acc:0.58 |
#                    | test loss: 0.69 | test acc: 0.6 |
#                    | N-Way train acc:0.93 | N-Way test acc:0.91
# ----------------------------------------------------------------------------------------
# [0.6mins] epoch: 200 | train loss:0.69 | train acc:0.62 |
#                    | test loss: 0.68 | test acc: 0.6 |
#                    | N-Way train acc:0.94 | N-Way test acc:0.93
# ----------------------------------------------------------------------------------------
# [0.8mins] epoch: 240 | train loss:0.68 | train acc:0.69 |
#                    | test loss: 0.68 | test acc: 0.75 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.91
# ----------------------------------------------------------------------------------------
# [0.9mins] epoch: 280 | train loss:0.66 | train acc:0.73 |
#                    | test loss: 0.66 | test acc: 0.74 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.95
# ----------------------------------------------------------------------------------------
# [1.1mins] epoch: 320 | train loss:0.62 | train acc:0.77 |
#                    | test loss: 0.62 | test acc: 0.77 |
#                    | N-Way train acc:0.95 | N-Way test acc:0.9
# ----------------------------------------------------------------------------------------
# [1.2mins] epoch: 360 | train loss:0.55 | train acc:0.83 |
#                    | test loss: 0.53 | test acc: 0.83 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.94
#           | best test acc: current=0.83 | previous=0.81)
# ----------------------------------------------------------------------------------------
# [1.4mins] epoch: 400 | train loss:0.49 | train acc:0.88 |
#                    | test loss: 0.51 | test acc: 0.81 |
#                    | N-Way train acc:0.92 | N-Way test acc:0.91
# ----------------------------------------------------------------------------------------
# [1.5mins] epoch: 440 | train loss:0.43 | train acc:0.9 |
#                    | test loss: 0.42 | test acc: 0.89 |
#                    | N-Way train acc:0.88 | N-Way test acc:0.91
#           | best test acc: current=0.89 | previous=0.83)
# ----------------------------------------------------------------------------------------
# [1.7mins] epoch: 480 | train loss:0.4 | train acc:0.91 |
#                    | test loss: 0.42 | test acc: 0.88 |
#                    | N-Way train acc:0.9 | N-Way test acc:0.9
# ----------------------------------------------------------------------------------------
# [1.8mins] epoch: 520 | train loss:0.36 | train acc:0.93 |
#                    | test loss: 0.38 | test acc: 0.88 |
#                    | N-Way train acc:0.92 | N-Way test acc:0.86
# ----------------------------------------------------------------------------------------
# [2.0mins] epoch: 560 | train loss:0.34 | train acc:0.94 |
#                    | test loss: 0.38 | test acc: 0.88 |
#                    | N-Way train acc:0.92 | N-Way test acc:0.94
# ----------------------------------------------------------------------------------------
# [2.1mins] epoch: 600 | train loss:0.32 | train acc:0.93 |
#                    | test loss: 0.34 | test acc: 0.9 |
#                    | N-Way train acc:0.94 | N-Way test acc:0.89
#           | best test acc: current=0.9 | previous=0.89)

# %% [markdown]
# ### embed_option: 'facenet1'

# %%
siamese_train(epochs=600, batch_size=256, train_type='batch', eval_freq=40, n_way=10, n_test=100, 
              embed=True, normalize=False, do_shuffle=True, 
              embed_option='facenet1', learn='before_after_l2')
# Out:
# starting oneshot training (evaluated by 10 N-Way for 100 times):
#  - epochs: 600 (eq.iters: 1800) - eval freq: 40 - batch_size: 256
# ----------------------------------------------------------------------------------------
# [0.0mins] epoch: 40 | train loss:0.61 | train acc:0.84 |
#                    | test loss: 0.62 | test acc: 0.79 |
#                    | N-Way train acc:0.99 | N-Way test acc:0.98
#           | best N-Way train acc: current=0.98 | previous=0)
#           | best test acc: current=0.79 | previous=0)
# ----------------------------------------------------------------------------------------
# [0.2mins] epoch: 80 | train loss:0.54 | train acc:0.95 |
#                    | test loss: 0.54 | test acc: 0.94 |
#                    | N-Way train acc:0.98 | N-Way test acc:0.88
#           | best test acc: current=0.94 | previous=0.79)
# ----------------------------------------------------------------------------------------
# [0.3mins] epoch: 120 | train loss:0.49 | train acc:0.97 |
#                    | test loss: 0.52 | test acc: 0.92 |
#                    | N-Way train acc:0.98 | N-Way test acc:0.89
# ----------------------------------------------------------------------------------------
# [0.4mins] epoch: 160 | train loss:0.45 | train acc:0.95 |
#                    | test loss: 0.46 | test acc: 0.96 |
#                    | N-Way train acc:0.99 | N-Way test acc:0.93
#           | best test acc: current=0.96 | previous=0.94)
# ----------------------------------------------------------------------------------------
# [0.6mins] epoch: 200 | train loss:0.42 | train acc:0.95 |
#                    | test loss: 0.44 | test acc: 0.94 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.88
# ----------------------------------------------------------------------------------------
# [0.7mins] epoch: 240 | train loss:0.36 | train acc:0.97 |
#                    | test loss: 0.44 | test acc: 0.92 |
#                    | N-Way train acc:0.98 | N-Way test acc:0.91
# ----------------------------------------------------------------------------------------
# [0.8mins] epoch: 280 | train loss:0.33 | train acc:0.98 |
#                    | test loss: 0.4 | test acc: 0.9 |
#                    | N-Way train acc:0.99 | N-Way test acc:0.93
# ----------------------------------------------------------------------------------------
# [0.9mins] epoch: 320 | train loss:0.29 | train acc:0.99 |
#                    | test loss: 0.41 | test acc: 0.89 |
#                    | N-Way train acc:1.0 | N-Way test acc:0.81
# ----------------------------------------------------------------------------------------
# [1.0mins] epoch: 360 | train loss:0.27 | train acc:0.99 |
#                    | test loss: 0.35 | test acc: 0.91 |
#                    | N-Way train acc:1.0 | N-Way test acc:0.9
# ----------------------------------------------------------------------------------------
# [1.2mins] epoch: 400 | train loss:0.24 | train acc:0.99 |
#                    | test loss: 0.38 | test acc: 0.88 |
#                    | N-Way train acc:0.99 | N-Way test acc:0.81
# ----------------------------------------------------------------------------------------
# [1.3mins] epoch: 440 | train loss:0.22 | train acc:0.99 |
#                    | test loss: 0.41 | test acc: 0.87 |
#                    | N-Way train acc:0.99 | N-Way test acc:0.86
# ----------------------------------------------------------------------------------------
# [1.4mins] epoch: 480 | train loss:0.21 | train acc:0.98 |
#                    | test loss: 0.36 | test acc: 0.9 |
#                    | N-Way train acc:1.0 | N-Way test acc:0.91
# ----------------------------------------------------------------------------------------
# [1.5mins] epoch: 520 | train loss:0.18 | train acc:1.0 |
#                    | test loss: 0.34 | test acc: 0.88 |
#                    | N-Way train acc:1.0 | N-Way test acc:0.86
# ----------------------------------------------------------------------------------------
# [1.7mins] epoch: 560 | train loss:0.17 | train acc:1.0 |
#                    | test loss: 0.35 | test acc: 0.87 |
#                    | N-Way train acc:0.99 | N-Way test acc:0.82
# ----------------------------------------------------------------------------------------
# [1.8mins] epoch: 600 | train loss:0.16 | train acc:1.0 |
#                    | test loss: 0.33 | test acc: 0.87 |
#                    | N-Way train acc:1.0 | N-Way test acc:0.85

# %%
siamese_train(epochs=600, batch_size=256, train_type='epoch', eval_freq=40, n_way=10, n_test=100, 
              embed=True, normalize=False, do_shuffle=True, 
              embed_option='facenet1', learn='before_after_l2')
# Out:
# starting oneshot training (evaluated by 10 N-Way for 100 times):
#  - epochs: 600 - eval freq: 40 - batch_size: 256
# ----------------------------------------------------------------------------------------
# [0.1mins] epoch: 40 | train loss:0.63 | train acc:0.89 |
#                    | test loss: 0.63 | test acc: 0.85 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.96
#           | best N-Way train acc: current=0.96 | previous=0)
#           | best test acc: current=0.85 | previous=0)
# ----------------------------------------------------------------------------------------
# [0.2mins] epoch: 80 | train loss:0.55 | train acc:0.95 |
#                    | test loss: 0.56 | test acc: 0.92 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.91
#           | best test acc: current=0.92 | previous=0.85)
# ----------------------------------------------------------------------------------------
# [0.3mins] epoch: 120 | train loss:0.49 | train acc:0.96 |
#                    | test loss: 0.51 | test acc: 0.93 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.92
#           | best test acc: current=0.93 | previous=0.92)
# ----------------------------------------------------------------------------------------
# [0.5mins] epoch: 160 | train loss:0.45 | train acc:0.96 |
#                    | test loss: 0.48 | test acc: 0.92 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.93
# ----------------------------------------------------------------------------------------
# [0.6mins] epoch: 200 | train loss:0.4 | train acc:0.97 |
#                    | test loss: 0.46 | test acc: 0.9 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.94
# ----------------------------------------------------------------------------------------
# [0.8mins] epoch: 240 | train loss:0.37 | train acc:0.96 |
#                    | test loss: 0.42 | test acc: 0.92 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.86
# ----------------------------------------------------------------------------------------
# [0.9mins] epoch: 280 | train loss:0.33 | train acc:0.97 |
#                    | test loss: 0.42 | test acc: 0.9 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.89
# ----------------------------------------------------------------------------------------
# [1.0mins] epoch: 320 | train loss:0.3 | train acc:0.98 |
#                    | test loss: 0.36 | test acc: 0.92 |
#                    | N-Way train acc:0.99 | N-Way test acc:0.89
# ----------------------------------------------------------------------------------------
# [1.2mins] epoch: 360 | train loss:0.27 | train acc:0.98 |
#                    | test loss: 0.36 | test acc: 0.9 |
#                    | N-Way train acc:0.98 | N-Way test acc:0.91
# ----------------------------------------------------------------------------------------
# [1.3mins] epoch: 400 | train loss:0.24 | train acc:0.98 |
#                    | test loss: 0.33 | test acc: 0.9 |
#                    | N-Way train acc:1.0 | N-Way test acc:0.91
# ----------------------------------------------------------------------------------------
# [1.5mins] epoch: 440 | train loss:0.22 | train acc:0.99 |
#                    | test loss: 0.37 | test acc: 0.87 |
#                    | N-Way train acc:1.0 | N-Way test acc:0.84
# ----------------------------------------------------------------------------------------
# [1.6mins] epoch: 480 | train loss:0.19 | train acc:1.0 |
#                    | test loss: 0.34 | test acc: 0.91 |
#                    | N-Way train acc:0.99 | N-Way test acc:0.92
# ----------------------------------------------------------------------------------------
# [1.8mins] epoch: 520 | train loss:0.18 | train acc:1.0 |
#                    | test loss: 0.34 | test acc: 0.89 |
#                    | N-Way train acc:1.0 | N-Way test acc:0.88
# ----------------------------------------------------------------------------------------
# [1.9mins] epoch: 560 | train loss:0.16 | train acc:1.0 |
#                    | test loss: 0.29 | test acc: 0.91 |
#                    | N-Way train acc:1.0 | N-Way test acc:0.86
# ----------------------------------------------------------------------------------------
# [2.0mins] epoch: 600 | train loss:0.15 | train acc:1.0 |
#                    | test loss: 0.32 | test acc: 0.88 |
#                    | N-Way train acc:1.0 | N-Way test acc:0.91

# %% [markdown]
# ### embed_option: 'facenet2'

# %%
siamese_train(epochs=600, batch_size=256, train_type='batch', eval_freq=40, n_way=10, n_test=100, 
              embed=True, normalize=False, do_shuffle=True, 
              embed_option='facenet2', learn='before_after_l2')
# Out:
# starting oneshot training (evaluated by 10 N-Way for 100 times):
#  - epochs: 600 (eq.iters: 1800) - eval freq: 40 - batch_size: 256
# ----------------------------------------------------------------------------------------
# [0.0mins] epoch: 40 | train loss:0.66 | train acc:0.84 |
#                    | test loss: 0.66 | test acc: 0.83 |
#                    | N-Way train acc:0.95 | N-Way test acc:0.97
#           | best N-Way train acc: current=0.97 | previous=0)
#           | best test acc: current=0.83 | previous=0)
# ----------------------------------------------------------------------------------------
# [0.2mins] epoch: 80 | train loss:0.57 | train acc:0.95 |
#                    | test loss: 0.58 | test acc: 0.94 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.96
#           | best test acc: current=0.94 | previous=0.83)
# ----------------------------------------------------------------------------------------
# [0.3mins] epoch: 120 | train loss:0.53 | train acc:0.95 |
#                    | test loss: 0.54 | test acc: 0.94 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.99
#           | best N-Way train acc: current=0.99 | previous=0.97)
# ----------------------------------------------------------------------------------------
# [0.4mins] epoch: 160 | train loss:0.5 | train acc:0.96 |
#                    | test loss: 0.5 | test acc: 0.93 |
#                    | N-Way train acc:0.93 | N-Way test acc:0.98
# ----------------------------------------------------------------------------------------
# [0.5mins] epoch: 200 | train loss:0.45 | train acc:0.96 |
#                    | test loss: 0.48 | test acc: 0.94 |
#                    | N-Way train acc:0.95 | N-Way test acc:0.96
# ----------------------------------------------------------------------------------------
# [0.7mins] epoch: 240 | train loss:0.43 | train acc:0.97 |
#                    | test loss: 0.45 | test acc: 0.93 |
#                    | N-Way train acc:0.99 | N-Way test acc:0.97
# ----------------------------------------------------------------------------------------
# [0.8mins] epoch: 280 | train loss:0.4 | train acc:0.96 |
#                    | test loss: 0.42 | test acc: 0.94 |
#                    | N-Way train acc:0.99 | N-Way test acc:0.95
# ----------------------------------------------------------------------------------------
# [0.9mins] epoch: 320 | train loss:0.37 | train acc:0.97 |
#                    | test loss: 0.4 | test acc: 0.95 |
#                    | N-Way train acc:0.98 | N-Way test acc:0.91
#           | best test acc: current=0.95 | previous=0.94)
# ----------------------------------------------------------------------------------------
# [1.0mins] epoch: 360 | train loss:0.33 | train acc:0.96 |
#                    | test loss: 0.39 | test acc: 0.91 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.96
# ----------------------------------------------------------------------------------------
# [1.1mins] epoch: 400 | train loss:0.32 | train acc:0.96 |
#                    | test loss: 0.41 | test acc: 0.9 |
#                    | N-Way train acc:0.99 | N-Way test acc:0.96
# ----------------------------------------------------------------------------------------
# [1.3mins] epoch: 440 | train loss:0.29 | train acc:0.97 |
#                    | test loss: 0.38 | test acc: 0.89 |
#                    | N-Way train acc:1.0 | N-Way test acc:0.88
# ----------------------------------------------------------------------------------------
# [1.4mins] epoch: 480 | train loss:0.28 | train acc:0.98 |
#                    | test loss: 0.35 | test acc: 0.93 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.84
# ----------------------------------------------------------------------------------------
# [1.5mins] epoch: 520 | train loss:0.26 | train acc:0.97 |
#                    | test loss: 0.33 | test acc: 0.92 |
#                    | N-Way train acc:0.99 | N-Way test acc:0.94
# ----------------------------------------------------------------------------------------
# [1.6mins] epoch: 560 | train loss:0.23 | train acc:0.98 |
#                    | test loss: 0.36 | test acc: 0.89 |
#                    | N-Way train acc:1.0 | N-Way test acc:0.9
# ----------------------------------------------------------------------------------------
# [1.8mins] epoch: 600 | train loss:0.2 | train acc:1.0 |
#                    | test loss: 0.33 | test acc: 0.9 |
#                    | N-Way train acc:1.0 | N-Way test acc:0.89

# %%
siamese_train(epochs=600, batch_size=256, train_type='epoch', eval_freq=40, n_way=10, n_test=100, 
              embed=True, normalize=False, do_shuffle=True, 
              embed_option='facenet2', learn='before_after_l2')
# Out:
# starting oneshot training (evaluated by 10 N-Way for 100 times):
#  - epochs: 600 - eval freq: 40 - batch_size: 256
# ----------------------------------------------------------------------------------------
# [0.1mins] epoch: 40 | train loss:0.64 | train acc:0.9 |
#                    | test loss: 0.64 | test acc: 0.89 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.9
#           | best N-Way train acc: current=0.9 | previous=0)
#           | best test acc: current=0.89 | previous=0)
# ----------------------------------------------------------------------------------------
# [0.2mins] epoch: 80 | train loss:0.56 | train acc:0.94 |
#                    | test loss: 0.55 | test acc: 0.96 |
#                    | N-Way train acc:0.95 | N-Way test acc:0.96
#           | best N-Way train acc: current=0.96 | previous=0.9)
#           | best test acc: current=0.96 | previous=0.89)
# ----------------------------------------------------------------------------------------
# [0.3mins] epoch: 120 | train loss:0.51 | train acc:0.94 |
#                    | test loss: 0.51 | test acc: 0.94 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.91
# ----------------------------------------------------------------------------------------
# [0.5mins] epoch: 160 | train loss:0.46 | train acc:0.96 |
#                    | test loss: 0.5 | test acc: 0.9 |
#                    | N-Way train acc:0.99 | N-Way test acc:0.93
# ----------------------------------------------------------------------------------------
# [0.7mins] epoch: 200 | train loss:0.41 | train acc:0.97 |
#                    | test loss: 0.44 | test acc: 0.93 |
#                    | N-Way train acc:0.99 | N-Way test acc:0.89
# ----------------------------------------------------------------------------------------
# [0.8mins] epoch: 240 | train loss:0.38 | train acc:0.97 |
#                    | test loss: 0.4 | test acc: 0.96 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.95
# ----------------------------------------------------------------------------------------
# [1.0mins] epoch: 280 | train loss:0.34 | train acc:0.97 |
#                    | test loss: 0.38 | test acc: 0.95 |
#                    | N-Way train acc:0.99 | N-Way test acc:0.95
# ----------------------------------------------------------------------------------------
# [1.1mins] epoch: 320 | train loss:0.31 | train acc:0.97 |
#                    | test loss: 0.37 | test acc: 0.92 |
#                    | N-Way train acc:0.99 | N-Way test acc:0.95
# ----------------------------------------------------------------------------------------
# [1.2mins] epoch: 360 | train loss:0.28 | train acc:0.98 |
#                    | test loss: 0.36 | test acc: 0.9 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.87
# ----------------------------------------------------------------------------------------
# [1.4mins] epoch: 400 | train loss:0.26 | train acc:0.98 |
#                    | test loss: 0.34 | test acc: 0.91 |
#                    | N-Way train acc:0.99 | N-Way test acc:0.91
# ----------------------------------------------------------------------------------------
# [1.5mins] epoch: 440 | train loss:0.24 | train acc:0.99 |
#                    | test loss: 0.3 | test acc: 0.93 |
#                    | N-Way train acc:0.99 | N-Way test acc:0.91
# ----------------------------------------------------------------------------------------
# [1.7mins] epoch: 480 | train loss:0.2 | train acc:0.99 |
#                    | test loss: 0.29 | test acc: 0.93 |
#                    | N-Way train acc:1.0 | N-Way test acc:0.9
# ----------------------------------------------------------------------------------------
# [1.8mins] epoch: 520 | train loss:0.19 | train acc:0.99 |
#                    | test loss: 0.3 | test acc: 0.96 |
#                    | N-Way train acc:1.0 | N-Way test acc:0.91
# ----------------------------------------------------------------------------------------
# [2.0mins] epoch: 560 | train loss:0.17 | train acc:1.0 |
#                    | test loss: 0.34 | test acc: 0.85 |
#                    | N-Way train acc:1.0 | N-Way test acc:0.93
# ----------------------------------------------------------------------------------------
# [2.1mins] epoch: 600 | train loss:0.15 | train acc:1.0 |
#                    | test loss: 0.33 | test acc: 0.89 |
#                    | N-Way train acc:0.99 | N-Way test acc:0.84

# %% [markdown]
# ## Learn After L2
#     - without normalization

# %% [markdown]
# ### embed_option: 'face_recognition'

# %%
siamese_train(epochs=600, batch_size=256, train_type='batch', eval_freq=40, n_way=10, n_test=100, 
              embed=True, normalize=False, do_shuffle=True, 
              embed_option='face_recognition', learn='after_l2')
# Out:
# starting oneshot training (evaluated by 10 N-Way for 100 times):
#  - epochs: 600 (eq.iters: 1800) - eval freq: 40 - batch_size: 256
# ----------------------------------------------------------------------------------------
# [0.0mins] epoch: 40 | train loss:0.69 | train acc:0.8 |
#                    | test loss: 0.69 | test acc: 0.82 |
#                    | N-Way train acc:0.93 | N-Way test acc:0.92
#           | best N-Way train acc: current=0.92 | previous=0)
#           | best test acc: current=0.82 | previous=0)
# ----------------------------------------------------------------------------------------
# [0.2mins] epoch: 80 | train loss:0.68 | train acc:0.74 |
#                    | test loss: 0.68 | test acc: 0.71 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.96
#           | best N-Way train acc: current=0.96 | previous=0.92)
# ----------------------------------------------------------------------------------------
# [0.3mins] epoch: 120 | train loss:0.67 | train acc:0.74 |
#                    | test loss: 0.67 | test acc: 0.68 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.95
# ----------------------------------------------------------------------------------------
# [0.4mins] epoch: 160 | train loss:0.67 | train acc:0.76 |
#                    | test loss: 0.67 | test acc: 0.81 |
#                    | N-Way train acc:0.91 | N-Way test acc:0.94
# ----------------------------------------------------------------------------------------
# [0.5mins] epoch: 200 | train loss:0.66 | train acc:0.86 |
#                    | test loss: 0.66 | test acc: 0.89 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.97
#           | best N-Way train acc: current=0.97 | previous=0.96)
#           | best test acc: current=0.89 | previous=0.82)
# ----------------------------------------------------------------------------------------
# [0.6mins] epoch: 240 | train loss:0.64 | train acc:0.89 |
#                    | test loss: 0.64 | test acc: 0.85 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.95
# ----------------------------------------------------------------------------------------
# [0.8mins] epoch: 280 | train loss:0.63 | train acc:0.94 |
#                    | test loss: 0.63 | test acc: 0.9 |
#                    | N-Way train acc:0.98 | N-Way test acc:0.97
#           | best test acc: current=0.9 | previous=0.89)
# ----------------------------------------------------------------------------------------
# [0.9mins] epoch: 320 | train loss:0.61 | train acc:0.96 |
#                    | test loss: 0.62 | test acc: 0.92 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.97
#           | best test acc: current=0.92 | previous=0.9)
# ----------------------------------------------------------------------------------------
# [1.0mins] epoch: 360 | train loss:0.59 | train acc:0.95 |
#                    | test loss: 0.6 | test acc: 0.94 |
#                    | N-Way train acc:0.94 | N-Way test acc:0.95
#           | best test acc: current=0.94 | previous=0.92)
# ----------------------------------------------------------------------------------------
# [1.1mins] epoch: 400 | train loss:0.59 | train acc:0.93 |
#                    | test loss: 0.58 | test acc: 0.96 |
#                    | N-Way train acc:0.94 | N-Way test acc:0.91
#           | best test acc: current=0.96 | previous=0.94)
# ----------------------------------------------------------------------------------------
# [1.3mins] epoch: 440 | train loss:0.56 | train acc:0.95 |
#                    | test loss: 0.57 | test acc: 0.93 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.93
# ----------------------------------------------------------------------------------------
# [1.4mins] epoch: 480 | train loss:0.56 | train acc:0.92 |
#                    | test loss: 0.56 | test acc: 0.93 |
#                    | N-Way train acc:0.98 | N-Way test acc:0.94
# ----------------------------------------------------------------------------------------
# [1.5mins] epoch: 520 | train loss:0.53 | train acc:0.98 |
#                    | test loss: 0.54 | test acc: 0.97 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.95
#           | best test acc: current=0.97 | previous=0.96)
# ----------------------------------------------------------------------------------------
# [1.6mins] epoch: 560 | train loss:0.53 | train acc:0.94 |
#                    | test loss: 0.53 | test acc: 0.96 |
#                    | N-Way train acc:0.98 | N-Way test acc:0.93
# ----------------------------------------------------------------------------------------
# [1.7mins] epoch: 600 | train loss:0.5 | train acc:0.97 |
#                    | test loss: 0.51 | test acc: 0.96 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.95

# %%
siamese_train(epochs=600, batch_size=256, train_type='epoch', eval_freq=40, n_way=10, n_test=100, 
              embed=True, normalize=False, do_shuffle=True, 
              embed_option='face_recognition', learn='after_l2')
# Out:
# starting oneshot training (evaluated by 10 N-Way for 100 times):
#  - epochs: 600 - eval freq: 40 - batch_size: 256
# ----------------------------------------------------------------------------------------
# [0.1mins] epoch: 40 | train loss:0.69 | train acc:0.82 |
#                    | test loss: 0.69 | test acc: 0.77 |
#                    | N-Way train acc:0.99 | N-Way test acc:0.95
#           | best N-Way train acc: current=0.95 | previous=0)
#           | best test acc: current=0.77 | previous=0)
# ----------------------------------------------------------------------------------------
# [0.2mins] epoch: 80 | train loss:0.69 | train acc:0.84 |
#                    | test loss: 0.69 | test acc: 0.76 |
#                    | N-Way train acc:0.94 | N-Way test acc:0.94
# ----------------------------------------------------------------------------------------
# [0.3mins] epoch: 120 | train loss:0.69 | train acc:0.73 |
#                    | test loss: 0.69 | test acc: 0.73 |
#                    | N-Way train acc:0.95 | N-Way test acc:0.97
#           | best N-Way train acc: current=0.97 | previous=0.95)
# ----------------------------------------------------------------------------------------
# [0.5mins] epoch: 160 | train loss:0.68 | train acc:0.63 |
#                    | test loss: 0.68 | test acc: 0.64 |
#                    | N-Way train acc:0.94 | N-Way test acc:0.95
# ----------------------------------------------------------------------------------------
# [0.6mins] epoch: 200 | train loss:0.68 | train acc:0.72 |
#                    | test loss: 0.68 | test acc: 0.73 |
#                    | N-Way train acc:0.95 | N-Way test acc:0.96
# ----------------------------------------------------------------------------------------
# [0.7mins] epoch: 240 | train loss:0.68 | train acc:0.71 |
#                    | test loss: 0.68 | test acc: 0.75 |
#                    | N-Way train acc:0.98 | N-Way test acc:0.92
# ----------------------------------------------------------------------------------------
# [0.9mins] epoch: 280 | train loss:0.67 | train acc:0.78 |
#                    | test loss: 0.67 | test acc: 0.83 |
#                    | N-Way train acc:0.93 | N-Way test acc:0.92
#           | best test acc: current=0.83 | previous=0.77)
# ----------------------------------------------------------------------------------------
# [1.0mins] epoch: 320 | train loss:0.67 | train acc:0.8 |
#                    | test loss: 0.67 | test acc: 0.77 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.93
# ----------------------------------------------------------------------------------------
# [1.2mins] epoch: 360 | train loss:0.66 | train acc:0.84 |
#                    | test loss: 0.66 | test acc: 0.86 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.97
#           | best test acc: current=0.86 | previous=0.83)
# ----------------------------------------------------------------------------------------
# [1.3mins] epoch: 400 | train loss:0.65 | train acc:0.89 |
#                    | test loss: 0.65 | test acc: 0.88 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.95
#           | best test acc: current=0.88 | previous=0.86)
# ----------------------------------------------------------------------------------------
# [1.5mins] epoch: 440 | train loss:0.64 | train acc:0.92 |
#                    | test loss: 0.64 | test acc: 0.94 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.97
#           | best test acc: current=0.94 | previous=0.88)
# ----------------------------------------------------------------------------------------
# [1.6mins] epoch: 480 | train loss:0.63 | train acc:0.93 |
#                    | test loss: 0.63 | test acc: 0.93 |
#                    | N-Way train acc:0.99 | N-Way test acc:0.93
# ----------------------------------------------------------------------------------------
# [1.8mins] epoch: 520 | train loss:0.61 | train acc:0.96 |
#                    | test loss: 0.61 | test acc: 0.95 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.97
#           | best test acc: current=0.95 | previous=0.94)
# ----------------------------------------------------------------------------------------
# [1.9mins] epoch: 560 | train loss:0.6 | train acc:0.96 |
#                    | test loss: 0.59 | test acc: 0.92 |
#                    | N-Way train acc:0.95 | N-Way test acc:0.91
# ----------------------------------------------------------------------------------------
# [2.0mins] epoch: 600 | train loss:0.58 | train acc:0.94 |
#                    | test loss: 0.57 | test acc: 0.95 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.92

# %% [markdown]
# ### embed_option: 'facenet1'

# %%
siamese_train(epochs=600, batch_size=256, train_type='batch', eval_freq=40, n_way=10, n_test=100, 
              embed=True, normalize=False, do_shuffle=True, 
              embed_option='facenet1', learn='after_l2')
# Out:
# starting oneshot training (evaluated by 10 N-Way for 100 times):
#  - epochs: 600 (eq.iters: 1800) - eval freq: 40 - batch_size: 256
# ----------------------------------------------------------------------------------------
# [0.0mins] epoch: 40 | train loss:0.59 | train acc:0.81 |
#                    | test loss: 0.59 | test acc: 0.78 |
#                    | N-Way train acc:0.98 | N-Way test acc:0.99
#           | best N-Way train acc: current=0.99 | previous=0)
#           | best test acc: current=0.78 | previous=0)
# ----------------------------------------------------------------------------------------
# [0.2mins] epoch: 80 | train loss:0.53 | train acc:0.93 |
#                    | test loss: 0.53 | test acc: 0.96 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.95
#           | best test acc: current=0.96 | previous=0.78)
# ----------------------------------------------------------------------------------------
# [0.3mins] epoch: 120 | train loss:0.48 | train acc:0.94 |
#                    | test loss: 0.51 | test acc: 0.93 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.96
# ----------------------------------------------------------------------------------------
# [0.4mins] epoch: 160 | train loss:0.46 | train acc:0.94 |
#                    | test loss: 0.46 | test acc: 0.93 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.96
# ----------------------------------------------------------------------------------------
# [0.5mins] epoch: 200 | train loss:0.44 | train acc:0.93 |
#                    | test loss: 0.45 | test acc: 0.93 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.95
# ----------------------------------------------------------------------------------------
# [0.7mins] epoch: 240 | train loss:0.42 | train acc:0.93 |
#                    | test loss: 0.43 | test acc: 0.92 |
#                    | N-Way train acc:0.98 | N-Way test acc:0.93
# ----------------------------------------------------------------------------------------
# [0.8mins] epoch: 280 | train loss:0.39 | train acc:0.95 |
#                    | test loss: 0.4 | test acc: 0.93 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.97
# ----------------------------------------------------------------------------------------
# [0.9mins] epoch: 320 | train loss:0.36 | train acc:0.96 |
#                    | test loss: 0.4 | test acc: 0.92 |
#                    | N-Way train acc:0.98 | N-Way test acc:0.9
# ----------------------------------------------------------------------------------------
# [1.0mins] epoch: 360 | train loss:0.36 | train acc:0.95 |
#                    | test loss: 0.36 | test acc: 0.95 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.96
# ----------------------------------------------------------------------------------------
# [1.1mins] epoch: 400 | train loss:0.36 | train acc:0.91 |
#                    | test loss: 0.37 | test acc: 0.92 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.93
# ----------------------------------------------------------------------------------------
# [1.3mins] epoch: 440 | train loss:0.34 | train acc:0.93 |
#                    | test loss: 0.35 | test acc: 0.93 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.92
# ----------------------------------------------------------------------------------------
# [1.4mins] epoch: 480 | train loss:0.32 | train acc:0.95 |
#                    | test loss: 0.36 | test acc: 0.94 |
#                    | N-Way train acc:0.98 | N-Way test acc:0.89
# ----------------------------------------------------------------------------------------
# [1.5mins] epoch: 520 | train loss:0.3 | train acc:0.94 |
#                    | test loss: 0.35 | test acc: 0.92 |
#                    | N-Way train acc:0.94 | N-Way test acc:0.94
# ----------------------------------------------------------------------------------------
# [1.6mins] epoch: 560 | train loss:0.32 | train acc:0.92 |
#                    | test loss: 0.29 | test acc: 0.96 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.91
# ----------------------------------------------------------------------------------------
# [1.8mins] epoch: 600 | train loss:0.29 | train acc:0.95 |
#                    | test loss: 0.31 | test acc: 0.91 |
#                    | N-Way train acc:0.95 | N-Way test acc:0.94

# %%
siamese_train(epochs=600, batch_size=256, train_type='epoch', eval_freq=40, n_way=10, n_test=100, 
              embed=True, normalize=False, do_shuffle=True, 
              embed_option='facenet1', learn='after_l2')
# Out:
# starting oneshot training (evaluated by 10 N-Way for 100 times):
#  - epochs: 600 - eval freq: 40 - batch_size: 256
# ----------------------------------------------------------------------------------------
# [0.1mins] epoch: 40 | train loss:0.59 | train acc:0.82 |
#                    | test loss: 0.59 | test acc: 0.82 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.94
#           | best N-Way train acc: current=0.94 | previous=0)
#           | best test acc: current=0.82 | previous=0)
# ----------------------------------------------------------------------------------------
# [0.2mins] epoch: 80 | train loss:0.52 | train acc:0.92 |
#                    | test loss: 0.54 | test acc: 0.94 |
#                    | N-Way train acc:0.91 | N-Way test acc:0.98
#           | best N-Way train acc: current=0.98 | previous=0.94)
#           | best test acc: current=0.94 | previous=0.82)
# ----------------------------------------------------------------------------------------
# [0.3mins] epoch: 120 | train loss:0.48 | train acc:0.94 |
#                    | test loss: 0.5 | test acc: 0.93 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.96
# ----------------------------------------------------------------------------------------
# [0.5mins] epoch: 160 | train loss:0.45 | train acc:0.93 |
#                    | test loss: 0.46 | test acc: 0.91 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.89
# ----------------------------------------------------------------------------------------
# [0.6mins] epoch: 200 | train loss:0.42 | train acc:0.94 |
#                    | test loss: 0.42 | test acc: 0.94 |
#                    | N-Way train acc:0.94 | N-Way test acc:0.92
# ----------------------------------------------------------------------------------------
# [0.8mins] epoch: 240 | train loss:0.39 | train acc:0.95 |
#                    | test loss: 0.41 | test acc: 0.93 |
#                    | N-Way train acc:0.98 | N-Way test acc:0.96
# ----------------------------------------------------------------------------------------
# [0.9mins] epoch: 280 | train loss:0.37 | train acc:0.95 |
#                    | test loss: 0.41 | test acc: 0.92 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.92
# ----------------------------------------------------------------------------------------
# [1.0mins] epoch: 320 | train loss:0.36 | train acc:0.94 |
#                    | test loss: 0.38 | test acc: 0.93 |
#                    | N-Way train acc:0.95 | N-Way test acc:0.99
#           | best N-Way train acc: current=0.99 | previous=0.98)
# ----------------------------------------------------------------------------------------
# [1.2mins] epoch: 360 | train loss:0.34 | train acc:0.95 |
#                    | test loss: 0.34 | test acc: 0.94 |
#                    | N-Way train acc:0.99 | N-Way test acc:0.98
# ----------------------------------------------------------------------------------------
# [1.3mins] epoch: 400 | train loss:0.32 | train acc:0.94 |
#                    | test loss: 0.34 | test acc: 0.94 |
#                    | N-Way train acc:0.92 | N-Way test acc:0.93
# ----------------------------------------------------------------------------------------
# [1.5mins] epoch: 440 | train loss:0.31 | train acc:0.94 |
#                    | test loss: 0.33 | test acc: 0.94 |
#                    | N-Way train acc:0.98 | N-Way test acc:0.92
# ----------------------------------------------------------------------------------------
# [1.6mins] epoch: 480 | train loss:0.3 | train acc:0.95 |
#                    | test loss: 0.31 | test acc: 0.95 |
#                    | N-Way train acc:0.95 | N-Way test acc:0.97
#           | best test acc: current=0.95 | previous=0.94)
# ----------------------------------------------------------------------------------------
# [1.8mins] epoch: 520 | train loss:0.28 | train acc:0.95 |
#                    | test loss: 0.32 | test acc: 0.94 |
#                    | N-Way train acc:0.99 | N-Way test acc:0.93
# ----------------------------------------------------------------------------------------
# [1.9mins] epoch: 560 | train loss:0.28 | train acc:0.95 |
#                    | test loss: 0.31 | test acc: 0.93 |
#                    | N-Way train acc:0.98 | N-Way test acc:0.94
# ----------------------------------------------------------------------------------------
# [2.1mins] epoch: 600 | train loss:0.26 | train acc:0.95 |
#                    | test loss: 0.24 | test acc: 0.99 |
#                    | N-Way train acc:0.98 | N-Way test acc:0.92
#           | best test acc: current=0.99 | previous=0.95)

# %% [markdown]
# ### embed_option: 'facenet2'

# %%
siamese_train(epochs=600, batch_size=256, train_type='batch', eval_freq=40, n_way=10, n_test=100, 
              embed=True, normalize=False, do_shuffle=True, 
              embed_option='facenet2', learn='after_l2')
# Out:
# starting oneshot training (evaluated by 10 N-Way for 100 times):
#  - epochs: 600 (eq.iters: 1800) - eval freq: 40 - batch_size: 256
# ----------------------------------------------------------------------------------------
# [0.0mins] epoch: 40 | train loss:0.64 | train acc:0.73 |
#                    | test loss: 0.64 | test acc: 0.73 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.91
#           | best N-Way train acc: current=0.91 | previous=0)
#           | best test acc: current=0.73 | previous=0)
# ----------------------------------------------------------------------------------------
# [0.2mins] epoch: 80 | train loss:0.55 | train acc:0.9 |
#                    | test loss: 0.55 | test acc: 0.92 |
#                    | N-Way train acc:0.98 | N-Way test acc:0.97
#           | best N-Way train acc: current=0.97 | previous=0.91)
#           | best test acc: current=0.92 | previous=0.73)
# ----------------------------------------------------------------------------------------
# [0.3mins] epoch: 120 | train loss:0.51 | train acc:0.93 |
#                    | test loss: 0.5 | test acc: 0.97 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.98
#           | best N-Way train acc: current=0.98 | previous=0.97)
#           | best test acc: current=0.97 | previous=0.92)
# ----------------------------------------------------------------------------------------
# [0.4mins] epoch: 160 | train loss:0.48 | train acc:0.93 |
#                    | test loss: 0.5 | test acc: 0.91 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.94
# ----------------------------------------------------------------------------------------
# [0.5mins] epoch: 200 | train loss:0.45 | train acc:0.94 |
#                    | test loss: 0.47 | test acc: 0.94 |
#                    | N-Way train acc:0.99 | N-Way test acc:0.92
# ----------------------------------------------------------------------------------------
# [0.7mins] epoch: 240 | train loss:0.43 | train acc:0.94 |
#                    | test loss: 0.43 | test acc: 0.95 |
#                    | N-Way train acc:1.0 | N-Way test acc:0.95
# ----------------------------------------------------------------------------------------
# [0.8mins] epoch: 280 | train loss:0.4 | train acc:0.94 |
#                    | test loss: 0.39 | test acc: 0.96 |
#                    | N-Way train acc:0.93 | N-Way test acc:0.94
# ----------------------------------------------------------------------------------------
# [0.9mins] epoch: 320 | train loss:0.38 | train acc:0.94 |
#                    | test loss: 0.42 | test acc: 0.93 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.91
# ----------------------------------------------------------------------------------------
# [1.0mins] epoch: 360 | train loss:0.39 | train acc:0.93 |
#                    | test loss: 0.39 | test acc: 0.94 |
#                    | N-Way train acc:0.99 | N-Way test acc:0.92
# ----------------------------------------------------------------------------------------
# [1.2mins] epoch: 400 | train loss:0.36 | train acc:0.95 |
#                    | test loss: 0.37 | test acc: 0.93 |
#                    | N-Way train acc:0.99 | N-Way test acc:0.97
# ----------------------------------------------------------------------------------------
# [1.3mins] epoch: 440 | train loss:0.35 | train acc:0.92 |
#                    | test loss: 0.34 | test acc: 0.95 |
#                    | N-Way train acc:0.93 | N-Way test acc:0.93
# ----------------------------------------------------------------------------------------
# [1.4mins] epoch: 480 | train loss:0.33 | train acc:0.96 |
#                    | test loss: 0.36 | test acc: 0.92 |
#                    | N-Way train acc:0.99 | N-Way test acc:0.92
# ----------------------------------------------------------------------------------------
# [1.5mins] epoch: 520 | train loss:0.32 | train acc:0.93 |
#                    | test loss: 0.36 | test acc: 0.9 |
#                    | N-Way train acc:1.0 | N-Way test acc:0.94
# ----------------------------------------------------------------------------------------
# [1.7mins] epoch: 560 | train loss:0.32 | train acc:0.93 |
#                    | test loss: 0.32 | test acc: 0.94 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.97
# ----------------------------------------------------------------------------------------
# [1.8mins] epoch: 600 | train loss:0.28 | train acc:0.96 |
#                    | test loss: 0.31 | test acc: 0.94 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.96

# %%
siamese_train(epochs=600, batch_size=256, train_type='epoch', eval_freq=40, n_way=10, n_test=100, 
              embed=True, normalize=False, do_shuffle=True, 
              embed_option='facenet2', learn='after_l2')
# Out:
# starting oneshot training (evaluated by 10 N-Way for 100 times):
#  - epochs: 600 - eval freq: 40 - batch_size: 256
# ----------------------------------------------------------------------------------------
# [0.1mins] epoch: 40 | train loss:0.6 | train acc:0.83 |
#                    | test loss: 0.6 | test acc: 0.81 |
#                    | N-Way train acc:0.95 | N-Way test acc:0.96
#           | best N-Way train acc: current=0.96 | previous=0)
#           | best test acc: current=0.81 | previous=0)
# ----------------------------------------------------------------------------------------
# [0.2mins] epoch: 80 | train loss:0.52 | train acc:0.93 |
#                    | test loss: 0.54 | test acc: 0.91 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.99
#           | best N-Way train acc: current=0.99 | previous=0.96)
#           | best test acc: current=0.91 | previous=0.81)
# ----------------------------------------------------------------------------------------
# [0.4mins] epoch: 120 | train loss:0.48 | train acc:0.94 |
#                    | test loss: 0.49 | test acc: 0.95 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.96
#           | best test acc: current=0.95 | previous=0.91)
# ----------------------------------------------------------------------------------------
# [0.5mins] epoch: 160 | train loss:0.45 | train acc:0.94 |
#                    | test loss: 0.45 | test acc: 0.97 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.96
#           | best test acc: current=0.97 | previous=0.95)
# ----------------------------------------------------------------------------------------
# [0.7mins] epoch: 200 | train loss:0.42 | train acc:0.94 |
#                    | test loss: 0.45 | test acc: 0.92 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.95
# ----------------------------------------------------------------------------------------
# [0.8mins] epoch: 240 | train loss:0.39 | train acc:0.95 |
#                    | test loss: 0.42 | test acc: 0.93 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.99
# ----------------------------------------------------------------------------------------
# [1.0mins] epoch: 280 | train loss:0.37 | train acc:0.94 |
#                    | test loss: 0.39 | test acc: 0.94 |
#                    | N-Way train acc:0.95 | N-Way test acc:0.95
# ----------------------------------------------------------------------------------------
# [1.1mins] epoch: 320 | train loss:0.35 | train acc:0.94 |
#                    | test loss: 0.37 | test acc: 0.92 |
#                    | N-Way train acc:0.93 | N-Way test acc:0.96
# ----------------------------------------------------------------------------------------
# [1.3mins] epoch: 360 | train loss:0.34 | train acc:0.95 |
#                    | test loss: 0.36 | test acc: 0.9 |
#                    | N-Way train acc:0.91 | N-Way test acc:0.94
# ----------------------------------------------------------------------------------------
# [1.4mins] epoch: 400 | train loss:0.33 | train acc:0.94 |
#                    | test loss: 0.34 | test acc: 0.96 |
#                    | N-Way train acc:0.95 | N-Way test acc:0.95
# ----------------------------------------------------------------------------------------
# [1.6mins] epoch: 440 | train loss:0.32 | train acc:0.93 |
#                    | test loss: 0.34 | test acc: 0.94 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.93
# ----------------------------------------------------------------------------------------
# [1.7mins] epoch: 480 | train loss:0.3 | train acc:0.94 |
#                    | test loss: 0.32 | test acc: 0.95 |
#                    | N-Way train acc:0.97 | N-Way test acc:0.96
# ----------------------------------------------------------------------------------------
# [1.9mins] epoch: 520 | train loss:0.29 | train acc:0.94 |
#                    | test loss: 0.31 | test acc: 0.96 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.93
# ----------------------------------------------------------------------------------------
# [2.0mins] epoch: 560 | train loss:0.28 | train acc:0.94 |
#                    | test loss: 0.29 | test acc: 0.96 |
#                    | N-Way train acc:0.96 | N-Way test acc:0.91
# ----------------------------------------------------------------------------------------
# [2.2mins] epoch: 600 | train loss:0.26 | train acc:0.95 |
#                    | test loss: 0.29 | test acc: 0.93 |
#                    | N-Way train acc:0.98 | N-Way test acc:0.96

# %% [markdown]
# ## Load Model Weights

# %%
def test_trained_models(model=None, model_type="image"):

    weights_path = "output/siamese_model/weights"
    model_weights = [name for name in os.listdir(weights_path) if model_type in name and name[-3:] == '.h5']
    
    for i, model_weight in enumerate(model_weights, start=1):
        print("test {} - model: {}".format(i, model_weight))
        model.load_weights(os.path.join(weights_path, model_weight))
        
        if 'nor' in model_weight:
            normalize = True
        else:
            normalize = False
        
        if 'embed' in model_weight:
            embed = True
        else:
            embed = False
        
        n_persons = (X_images_test.shape[0]//2)+1
        N_ways = np.arange(0, n_persons, 5)
        N_ways[0] = 1
        trials = 10

        test_accs, train_accs, = [], []
        for N_way in N_ways:    
            train_accs.append(100*test_oneshot(model, N_way, trials, True, embed, normalize, verbose=False))
            test_accs.append(100*test_oneshot(model, N_way, trials, False, embed, normalize, verbose=False))
        
        fig,ax = plt.subplots(1, figsize=(10,5))
        ax.plot(N_ways, test_accs, "m", label="Test.Acc")
        ax.plot(N_ways, train_accs, "y", label="Train.Acc")
        ax.plot(N_ways, 100.0/N_ways, "g", label="Random guessing")
        plt.xlabel("Number of possible classes in one-shot task")
        plt.ylabel("% Accuracy")
        plt.title("One-Shot Learning ({})".format(model_weight))
        ax.legend(loc='upper right')
        plt.show()

# %%
test_trained_models(embeds_model, model_type="embeds")
# Out:
# test 1 - model: batch_nor_embeds_bs256_ep680_test_best.h5
# test 2 - model: epoch_nor_embeds_bs256_ep680_nway_best.h5
# test 3 - model: epoch_embeds_bs256_ep680_nway_best.h5
# test 4 - model: epoch_embeds_bs256_ep680_test_best.h5
# test 5 - model: batch_embeds_bs256_ep680_nway_best.h5
# test 6 - model: init_embeds_train_weights.h5
# test 7 - model: epoch_nor_embeds_bs256_ep680_final.h5
# test 8 - model: batch_embeds_bs256_ep680_test_best.h5
# test 9 - model: epoch_embeds_bs256_ep680_final.h5
# test 10 - model: batch_nor_embeds_bs256_ep680_final.h5
# test 11 - model: batch_embeds_bs256_ep680_final.h5
# test 12 - model: batch_nor_embeds_bs256_ep680_nway_best.h5
# test 13 - model: epoch_nor_embeds_bs256_ep680_test_best.h5

# %% [raw]
# test_trained_models(images_model, model_type="images")

# %% [markdown]
# ### Examples:

# %%
def load_model(model, weights):
    
    weights_path = "output/siamese_model/weights/" + weights
    model.load_weights(weights_path)
    model.save("output/siamese_model/epoch_embeds_bs256_ep680_test_best.h5")
    return model
    
model = load_model(embeds_model,'epoch_embeds_bs256_ep680_test_best.h5')

# %%
pairs, targets = get_pairs(10, False, True, False, do_shuffle=False)
pairs[0].shape
# Out:
# (10, 128, 1)

# %%
model.predict(pairs)
# Out:
# array([[0.47429353],
#        [0.4829782 ],
#        [0.46227938],
#        [0.45999718],
#        [0.45164144],
#        [0.56703997],
#        [0.53430146],
#        [0.48806864],
#        [0.53078973],
#        [0.57020324]], dtype=float32)

# %%
np.expand_dims(pairs[0][0], axis=0).shape
# Out:
# (1, 128, 1)
